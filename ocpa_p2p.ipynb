# %% [markdown]
# ## Dataset Used: p2p-2023.jsoncel from ocpa github sample logs

# %% [markdown]
# # Importing Event Log

# %%
import ocpa
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
p2p = "p2p-2023.jsonocel"
ocel_p2p = ocel_import_factory.apply(p2p)

# the filetype of the datasets posted on the ocel website does not match the ocpm documentation input filetype
# json vs jsonocel

# %% [markdown]
# # Process Discovery

# %%
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory
from ocpa.visualization.oc_petri_net import factory as ocpn_vis_factory
ocpn_p2p = ocpn_discovery_factory.apply(ocel_p2p, parameters={"debug": False})
ocpn_vis_factory.save(ocpn_vis_factory.apply(ocpn_p2p), "ocpn_p2p.png")

# %%
#view the ocpm petri net
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("ocpn_p2p.png")
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()

# %%
#variant calculation and layouting
#The variant layouting just returns a positioning of chevrons as coordinates.
#Instead of drawing the entire process flow directly, the layout algorithm only computes coordinates (X, Y positions) for these elements, 
#so they can be plotted or displayed.


from ocpa.visualization.log.variants import factory as variants_visualization_factory
print("Number of process executions: "+str(len(ocel_p2p.process_executions)))
print("Number of variants: "+str(len(ocel_p2p.variants)))
variant_layouting = variants_visualization_factory.apply(ocel_p2p)
print(variant_layouting[ocel_p2p.variants[0]])
# Out:
# Number of process executions: 516
# Number of variants: 315
# ([['Create Invoice Receipt', [[6, 6], [1, 0]]], ['Perform Two-Way Match', [[7, 7], [1, 0]]], ['Create Goods Receipt', [[5, 5], [4, 0]]], ['Approve Purchase Requisition', [[1, 1], [2, 5]]], ['Execute Payment', [[8, 8], [3, 1, 4, 0]]], ['Create Request for Quotation', [[2, 2], [6, 5]]], ['Create Purchase Requisition', [[0, 0], [2, 5]]], ['Approve Purchase Order', [[4, 4], [6, 4]]], ['Create Purchase Order', [[3, 3], [6, 4]]]], {0: ('goods receipt', 'goods receipt_1'), 1: ('invoice receipt', 'invoice receipt_1'), 2: ('material', 'material_1'), 3: ('payment', 'payment_1'), 4: ('purchase_order', 'purchase_order_1'), 5: ('purchase_requisition', 'purchase_requisition_1'), 6: ('quotation', 'quotation_1')})

# %% [markdown]
# Consists of 7 objects, purchase order, quotation, material, goods receipt, payment, purchase_requisition, invoice receipt. In general only the objects goods receipt and material are multiples. Confirmed by ocpi.

# %% [markdown]
# # Precision and Fitness

# %%
from ocpa.algo.conformance.precision_and_fitness import evaluator as quality_measure_factory

precision, fitness = quality_measure_factory.apply(ocel_p2p, ocpn_p2p)
print("Precision of IM-discovered net: "+str(precision))
print("Fitness of IM-discovered net: "+str(fitness))
#too long compilation, going over an hour and still no output (maybe cause of the flattening>metrics>combining), try on some high end pc later.
# Out:
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event
# Aborting: Timeout single event

# %% [markdown]
# # Filtered Log

# %% [markdown]
# Filtering variants as precision and fitness gets stuck in a never ending compile loop

# %% [markdown]
# #from ocpa.examplescripts.eventlogmanagement.misc.filter_variants
# # 20% of infrequent variants filtered out
#
# from ocpa.algo.util.filtering.log.variant_filtering import filter_infrequent_variants
# from ocpa.algo.util.process_executions.factory.LEAD_TYPE
# object_types = ["application", "offer"]
# parameters = {"obj_names": object_types,
#               "val_names": [],
#               "act_name": "event_activity",
#               "time_name": "event_timestamp",
#               "sep": ",",
#               "execution_extraction": ocpa.algo.util.process_executions.factory.LEAD_TYPE,
#               "leading_type": object_types[0],
#               "variant_calculation": ocpa.algo.util.variants.factory.TWO_PHASE}
# ocel_fil = ocel_import_factory.apply(file_path=filename, parameters=parameters)
# filtered = filter_infrequent_variants(ocel_fil, 0.2)

# %%
from ocpa.objects.log.util import misc as log_util


def filter_infrequent_variants(ocel, threshold):
    '''
    Filters infrequent variants from an OCEL

    :param ocel: Object-centric event log
    :type ocel: :class:`OCEL <ocpa.objects.log.ocel.OCEL>`

    :param threshold: Cumulative frequency of the most frequent variants to be included.
    :type threshold: float

    :return: Object-centric event log
    :rtype: :class:`OCEL <ocpa.objects.log.ocel.OCEL>`

    '''
    ocel = log_util.copy_log(ocel)
    if threshold > 0.9999:
        return ocel
    v_freq_acc = [sum(ocel.variant_frequencies[0:i+1])
                  for i in range(0, len(ocel.variant_frequencies))]
    last_filtered_variant = len(v_freq_acc)-1
    filtered_variants = []
    for i in range(0, len(v_freq_acc)):
        filtered_variants.append(i)
        if v_freq_acc[i] > threshold:
            last_filtered_variant = i
            break
    # get the relevant objects
    rel_obs = log_util.get_objects_of_variants(ocel, filtered_variants)
    pref_sublog = log_util.remove_object_references(
        ocel.log.log, ocel.object_types, rel_obs)
    sublog = pref_sublog[pref_sublog["event_variant"].apply(
        lambda x: bool(set(x) & set(filtered_variants)))].copy()
    sublog = sublog.drop("event_variant", axis=1)
    sublog = log_util.remove_object_references(
        sublog, ocel.object_types, rel_obs)
    new_log = log_util.copy_log_from_df(sublog, ocel.parameters)
    return new_log

filtered_p2p= filter_infrequent_variants(ocel_p2p,0.1)
#anything higher than 0.1 doesnt work

# %% [markdown]
# Filtered Process Discovery

# %%
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory
from ocpa.visualization.oc_petri_net import factory as ocpn_vis_factory

ocpn_fil_p2p = ocpn_discovery_factory.apply(filtered_p2p, parameters={"debug": False})
print(type(ocpn_fil_p2p))  # Should be an OCPN object, not OCEL
# Out:
# <class 'ocpa.objects.oc_petri_net.obj.ObjectCentricPetriNet'>

# %%
ocpn_vis_factory.save(ocpn_vis_factory.apply(ocpn_fil_p2p), "ocpn_fil_p2p.png")

# %%
img = mpimg.imread("ocpn_fil_p2p.png")
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()

# %%
from ocpa.algo.conformance.precision_and_fitness import evaluator as quality_measure_factory

precision, fitness = quality_measure_factory.apply(filtered_p2p, ocpn_fil_p2p)
print("Precision of IM-discovered net: "+str(precision))
print("Fitness of IM-discovered net: "+str(fitness))
# perfect result (unexpected)
# Out:
# Precision of IM-discovered net: 1.0
# Fitness of IM-discovered net: 1.0

# %%
from ocpa.objects.log.exporter.ocel import factory as ocel_export_factory
ocel_export_factory.apply(
    filtered_p2p, './filtered-p2p.jsonocel')
# Out:
# {'ocel:global-log': {'ocel:attribute-names': ['event_resource',
#    'event_lifecycle',
#    'event_id'],
#   'ocel:object-types': ['goods receipt',
#    'material',
#    'quotation',
#    'purchase_requisition',
#    'invoice receipt',
#    'purchase_order',
#    'payment'],
#   'ocel:version': '1.0',
#   'ocel:ordering': 'timestamp'},
#  'ocel:global-event': {'ocel:activity': '__INVALID__'},
#  'ocel:global-object': {'ocel:type': '__INVALID__'},
#  'ocel:events': {'23': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-04-11T13:39:00+02:00',
#    'ocel:omap': ['material:36', 'purchase_requisition:11:pr_trigger_11'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 23,
#     'start_timestamp': Timestamp('2022-04-11 13:39:00+0200', tz='UTC+02:00')}},
#   '49': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-04-16T09:30:00+02:00',
#    'ocel:omap': ['material:36', 'purchase_requisition:11:pr_trigger_11'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 49,
#     'start_timestamp': Timestamp('2022-04-16 09:30:00+0200', tz='UTC+02:00')}},
#   '54': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-04-18T09:15:00+02:00',
#    'ocel:omap': ['quotation:14', 'purchase_requisition:11:pr_trigger_11'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 54,
#     'start_timestamp': Timestamp('2022-04-18 09:15:00+0200', tz='UTC+02:00')}},
#   '59': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-04-19T05:46:00+02:00',
#    'ocel:omap': ['quotation:14', 'purchase_order:20'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 59,
#     'start_timestamp': Timestamp('2022-04-19 05:46:00+0200', tz='UTC+02:00')}},
#   '89': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-04-22T01:17:00+02:00',
#    'ocel:omap': ['quotation:14', 'purchase_order:20'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 89,
#     'start_timestamp': Timestamp('2022-04-22 01:17:00+0200', tz='UTC+02:00')}},
#   '111': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-04-25T02:16:00+02:00',
#    'ocel:omap': ['goods receipt:19', 'purchase_order:20'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 111,
#     'start_timestamp': Timestamp('2022-04-25 02:16:00+0200', tz='UTC+02:00')}},
#   '114': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-04-25T09:25:00+02:00',
#    'ocel:omap': ['material:88', 'purchase_requisition:27:pr_trigger_27'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 114,
#     'start_timestamp': Timestamp('2022-04-25 09:25:00+0200', tz='UTC+02:00')}},
#   '119': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-04-25T11:16:00+02:00',
#    'ocel:omap': ['material:87', 'purchase_requisition:26:pr_trigger_26'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 119,
#     'start_timestamp': Timestamp('2022-04-25 11:16:00+0200', tz='UTC+02:00')}},
#   '129': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-04-26T01:04:00+02:00',
#    'ocel:omap': ['goods receipt:19', 'invoice receipt:6'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 129,
#     'start_timestamp': Timestamp('2022-04-26 01:04:00+0200', tz='UTC+02:00')}},
#   '136': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-04-26T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:19', 'invoice receipt:6'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 136,
#     'start_timestamp': Timestamp('2022-04-26 09:10:00+0200', tz='UTC+02:00')}},
#   '145': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-04-26T13:47:00+02:00',
#    'ocel:omap': ['material:88', 'purchase_requisition:27:pr_trigger_27'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 145,
#     'start_timestamp': Timestamp('2022-04-26 13:47:00+0200', tz='UTC+02:00')}},
#   '158': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-04-28T00:13:00+02:00',
#    'ocel:omap': ['quotation:25', 'purchase_requisition:27:pr_trigger_27'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 158,
#     'start_timestamp': Timestamp('2022-04-28 00:13:00+0200', tz='UTC+02:00')}},
#   '201': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-05-02T07:32:00+02:00',
#    'ocel:omap': ['quotation:25', 'purchase_order:44'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 201,
#     'start_timestamp': Timestamp('2022-05-02 07:32:00+0200', tz='UTC+02:00')}},
#   '270': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-05-06T15:30:00+02:00',
#    'ocel:omap': ['quotation:25', 'purchase_order:44'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 270,
#     'start_timestamp': Timestamp('2022-05-06 15:30:00+0200', tz='UTC+02:00')}},
#   '274': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-05-06T19:54:00+02:00',
#    'ocel:omap': ['goods receipt:19',
#     'invoice receipt:6',
#     'purchase_order:20',
#     'payment:0'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 274,
#     'start_timestamp': Timestamp('2022-05-06 19:54:00+0200', tz='UTC+02:00')}},
#   '285': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-05-07T23:31:00+02:00',
#    'ocel:omap': ['material:87', 'purchase_requisition:26:pr_trigger_26'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 285,
#     'start_timestamp': Timestamp('2022-05-07 23:31:00+0200', tz='UTC+02:00')}},
#   '299': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-05-09T15:47:00+02:00',
#    'ocel:omap': ['material:121', 'purchase_requisition:40:pr_trigger_40'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 299,
#     'start_timestamp': Timestamp('2022-05-09 15:47:00+0200', tz='UTC+02:00')}},
#   '303': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-05-09T19:50:00+02:00',
#    'ocel:omap': ['quotation:35', 'purchase_requisition:26:pr_trigger_26'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 303,
#     'start_timestamp': Timestamp('2022-05-09 19:50:00+0200', tz='UTC+02:00')}},
#   '332': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-05-11T11:41:00+02:00',
#    'ocel:omap': ['material:128', 'purchase_requisition:44:pr_trigger_44'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 332,
#     'start_timestamp': Timestamp('2022-05-11 11:41:00+0200', tz='UTC+02:00')}},
#   '380': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-05-15T03:11:00+02:00',
#    'ocel:omap': ['material:128', 'purchase_requisition:44:pr_trigger_44'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 380,
#     'start_timestamp': Timestamp('2022-05-15 03:11:00+0200', tz='UTC+02:00')}},
#   '385': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-05-15T11:01:00+02:00',
#    'ocel:omap': ['quotation:35', 'purchase_order:59'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 385,
#     'start_timestamp': Timestamp('2022-05-15 11:01:00+0200', tz='UTC+02:00')}},
#   '386': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-05-15T11:18:00+02:00',
#    'ocel:omap': ['material:121', 'purchase_requisition:40:pr_trigger_40'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 386,
#     'start_timestamp': Timestamp('2022-05-15 11:18:00+0200', tz='UTC+02:00')}},
#   '394': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-05-16T10:49:00+02:00',
#    'ocel:omap': ['quotation:43', 'purchase_requisition:40:pr_trigger_40'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 394,
#     'start_timestamp': Timestamp('2022-05-16 10:49:00+0200', tz='UTC+02:00')}},
#   '399': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-05-16T14:31:00+02:00',
#    'ocel:omap': ['quotation:35', 'purchase_order:59'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 399,
#     'start_timestamp': Timestamp('2022-05-16 14:31:00+0200', tz='UTC+02:00')}},
#   '403': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-05-16T21:36:00+02:00',
#    'ocel:omap': ['quotation:42', 'purchase_requisition:44:pr_trigger_44'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 403,
#     'start_timestamp': Timestamp('2022-05-16 21:36:00+0200', tz='UTC+02:00')}},
#   '450': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-05-19T11:35:00+02:00',
#    'ocel:omap': ['quotation:42', 'purchase_order:72'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 450,
#     'start_timestamp': Timestamp('2022-05-19 11:35:00+0200', tz='UTC+02:00')}},
#   '473': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-05-20T16:35:00+02:00',
#    'ocel:omap': ['material:134', 'purchase_requisition:48:pr_trigger_48'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 473,
#     'start_timestamp': Timestamp('2022-05-20 16:35:00+0200', tz='UTC+02:00')}},
#   '475': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-05-20T17:21:00+02:00',
#    'ocel:omap': ['quotation:43', 'purchase_order:69'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 475,
#     'start_timestamp': Timestamp('2022-05-20 17:21:00+0200', tz='UTC+02:00')}},
#   '482': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-05-21T09:05:00+02:00',
#    'ocel:omap': ['material:134', 'purchase_requisition:48:pr_trigger_48'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 482,
#     'start_timestamp': Timestamp('2022-05-21 09:05:00+0200', tz='UTC+02:00')}},
#   '488': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-05-21T20:49:00+02:00',
#    'ocel:omap': ['goods receipt:41', 'purchase_order:44'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 488,
#     'start_timestamp': Timestamp('2022-05-21 20:49:00+0200', tz='UTC+02:00')}},
#   '506': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-05-23T13:34:00+02:00',
#    'ocel:omap': ['quotation:46', 'purchase_requisition:48:pr_trigger_48'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 506,
#     'start_timestamp': Timestamp('2022-05-23 13:34:00+0200', tz='UTC+02:00')}},
#   '507': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-05-23T13:42:00+02:00',
#    'ocel:omap': ['goods receipt:63', 'purchase_order:59'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 507,
#     'start_timestamp': Timestamp('2022-05-23 13:42:00+0200', tz='UTC+02:00')}},
#   '515': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-05-24T08:00:00+02:00',
#    'ocel:omap': ['goods receipt:63', 'invoice receipt:62'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 515,
#     'start_timestamp': Timestamp('2022-05-24 08:00:00+0200', tz='UTC+02:00')}},
#   '517': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-05-24T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:63', 'invoice receipt:62'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 517,
#     'start_timestamp': Timestamp('2022-05-24 09:10:00+0200', tz='UTC+02:00')}},
#   '534': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-05-25T14:27:00+02:00',
#    'ocel:omap': ['quotation:43', 'purchase_order:69'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 534,
#     'start_timestamp': Timestamp('2022-05-25 14:27:00+0200', tz='UTC+02:00')}},
#   '553': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-05-26T18:14:00+02:00',
#    'ocel:omap': ['quotation:42', 'purchase_order:72'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 553,
#     'start_timestamp': Timestamp('2022-05-26 18:14:00+0200', tz='UTC+02:00')}},
#   '639': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-06-03T05:52:00+02:00',
#    'ocel:omap': ['goods receipt:85', 'purchase_order:69'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 639,
#     'start_timestamp': Timestamp('2022-06-03 05:52:00+0200', tz='UTC+02:00')}},
#   '650': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-06-03T20:30:00+02:00',
#    'ocel:omap': ['quotation:46', 'purchase_order:76'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 650,
#     'start_timestamp': Timestamp('2022-06-03 20:30:00+0200', tz='UTC+02:00')}},
#   '652': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-06-04T00:03:00+02:00',
#    'ocel:omap': ['goods receipt:85', 'invoice receipt:82'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 652,
#     'start_timestamp': Timestamp('2022-06-04 00:03:00+0200', tz='UTC+02:00')}},
#   '669': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-06-05T05:34:00+02:00',
#    'ocel:omap': ['goods receipt:41', 'invoice receipt:58'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 669,
#     'start_timestamp': Timestamp('2022-06-05 05:34:00+0200', tz='UTC+02:00')}},
#   '670': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-06-05T05:50:00+02:00',
#    'ocel:omap': ['goods receipt:63',
#     'invoice receipt:62',
#     'purchase_order:59',
#     'payment:22'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 670,
#     'start_timestamp': Timestamp('2022-06-05 05:50:00+0200', tz='UTC+02:00')}},
#   '679': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-06-06T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:41', 'invoice receipt:58'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 679,
#     'start_timestamp': Timestamp('2022-06-06 09:10:00+0200', tz='UTC+02:00')}},
#   '683': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-06-06T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:85', 'invoice receipt:82'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 683,
#     'start_timestamp': Timestamp('2022-06-06 09:10:00+0200', tz='UTC+02:00')}},
#   '699': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-06-07T15:33:00+02:00',
#    'ocel:omap': ['goods receipt:41',
#     'invoice receipt:58',
#     'purchase_order:44',
#     'payment:31'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 699,
#     'start_timestamp': Timestamp('2022-06-07 15:33:00+0200', tz='UTC+02:00')}},
#   '730': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-06-09T16:41:00+02:00',
#    'ocel:omap': ['material:189', 'purchase_requisition:67:pr_trigger_67'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 730,
#     'start_timestamp': Timestamp('2022-06-09 16:41:00+0200', tz='UTC+02:00')}},
#   '733': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-06-09T20:32:00+02:00',
#    'ocel:omap': ['material:189', 'purchase_requisition:67:pr_trigger_67'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 733,
#     'start_timestamp': Timestamp('2022-06-09 20:32:00+0200', tz='UTC+02:00')}},
#   '750': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-06-10T21:02:00+02:00',
#    'ocel:omap': ['quotation:67', 'purchase_requisition:67:pr_trigger_67'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 750,
#     'start_timestamp': Timestamp('2022-06-10 21:02:00+0200', tz='UTC+02:00')}},
#   '780': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-06-13T14:12:00+02:00',
#    'ocel:omap': ['material:197', 'purchase_requisition:71:pr_trigger_71'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 780,
#     'start_timestamp': Timestamp('2022-06-13 14:12:00+0200', tz='UTC+02:00')}},
#   '814': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-06-14T18:03:00+02:00',
#    'ocel:omap': ['quotation:46', 'purchase_order:76'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 814,
#     'start_timestamp': Timestamp('2022-06-14 18:03:00+0200', tz='UTC+02:00')}},
#   '819': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-06-15T03:47:00+02:00',
#    'ocel:omap': ['quotation:67', 'purchase_order:109'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 819,
#     'start_timestamp': Timestamp('2022-06-15 03:47:00+0200', tz='UTC+02:00')}},
#   '828': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-06-15T18:46:00+02:00',
#    'ocel:omap': ['quotation:67', 'purchase_order:109'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 828,
#     'start_timestamp': Timestamp('2022-06-15 18:46:00+0200', tz='UTC+02:00')}},
#   '832': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-06-16T02:00:00+02:00',
#    'ocel:omap': ['material:202', 'purchase_requisition:73:pr_trigger_73'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 832,
#     'start_timestamp': Timestamp('2022-06-16 02:00:00+0200', tz='UTC+02:00')}},
#   '847': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-06-17T12:23:00+02:00',
#    'ocel:omap': ['material:202', 'purchase_requisition:73:pr_trigger_73'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 847,
#     'start_timestamp': Timestamp('2022-06-17 12:23:00+0200', tz='UTC+02:00')}},
#   '851': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-06-17T16:36:00+02:00',
#    'ocel:omap': ['quotation:73', 'purchase_requisition:73:pr_trigger_73'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 851,
#     'start_timestamp': Timestamp('2022-06-17 16:36:00+0200', tz='UTC+02:00')}},
#   '852': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-06-17T21:16:00+02:00',
#    'ocel:omap': ['material:197', 'purchase_requisition:71:pr_trigger_71'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 852,
#     'start_timestamp': Timestamp('2022-06-17 21:16:00+0200', tz='UTC+02:00')}},
#   '866': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-06-19T15:50:00+02:00',
#    'ocel:omap': ['goods receipt:88', 'purchase_order:72'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 866,
#     'start_timestamp': Timestamp('2022-06-19 15:50:00+0200', tz='UTC+02:00')}},
#   '896': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-06-20T23:05:00+02:00',
#    'ocel:omap': ['goods receipt:88', 'invoice receipt:109'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 896,
#     'start_timestamp': Timestamp('2022-06-20 23:05:00+0200', tz='UTC+02:00')}},
#   '899': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-06-21T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:88', 'invoice receipt:109'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 899,
#     'start_timestamp': Timestamp('2022-06-21 09:10:00+0200', tz='UTC+02:00')}},
#   '908': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-06-22T02:25:00+02:00',
#    'ocel:omap': ['quotation:74', 'purchase_requisition:71:pr_trigger_71'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 908,
#     'start_timestamp': Timestamp('2022-06-22 02:25:00+0200', tz='UTC+02:00')}},
#   '940': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-06-24T00:35:00+02:00',
#    'ocel:omap': ['goods receipt:116', 'purchase_order:76'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 940,
#     'start_timestamp': Timestamp('2022-06-24 00:35:00+0200', tz='UTC+02:00')}},
#   '941': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-06-24T04:56:00+02:00',
#    'ocel:omap': ['goods receipt:85',
#     'invoice receipt:82',
#     'purchase_order:69',
#     'payment:35'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 941,
#     'start_timestamp': Timestamp('2022-06-24 04:56:00+0200', tz='UTC+02:00')}},
#   '967': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-06-26T12:23:00+02:00',
#    'ocel:omap': ['goods receipt:88',
#     'invoice receipt:109',
#     'purchase_order:72',
#     'payment:48'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 967,
#     'start_timestamp': Timestamp('2022-06-26 12:23:00+0200', tz='UTC+02:00')}},
#   '969': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-06-26T16:07:00+02:00',
#    'ocel:omap': ['quotation:74', 'purchase_order:122'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 969,
#     'start_timestamp': Timestamp('2022-06-26 16:07:00+0200', tz='UTC+02:00')}},
#   '972': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-06-27T00:01:00+02:00',
#    'ocel:omap': ['quotation:73', 'purchase_order:120'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 972,
#     'start_timestamp': Timestamp('2022-06-27 00:01:00+0200', tz='UTC+02:00')}},
#   '997': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-06-28T03:49:00+02:00',
#    'ocel:omap': ['quotation:73', 'purchase_order:120'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 997,
#     'start_timestamp': Timestamp('2022-06-28 03:49:00+0200', tz='UTC+02:00')}},
#   '1015': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-06-29T10:41:00+02:00',
#    'ocel:omap': ['goods receipt:147', 'purchase_order:120'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1015,
#     'start_timestamp': Timestamp('2022-06-29 10:41:00+0200', tz='UTC+02:00')}},
#   '1031': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-06-30T07:39:00+02:00',
#    'ocel:omap': ['quotation:74', 'purchase_order:122'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1031,
#     'start_timestamp': Timestamp('2022-06-30 07:39:00+0200', tz='UTC+02:00')}},
#   '1044': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-06-30T22:00:00+02:00',
#    'ocel:omap': ['goods receipt:116', 'invoice receipt:118'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1044,
#     'start_timestamp': Timestamp('2022-06-30 22:00:00+0200', tz='UTC+02:00')}},
#   '1051': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-07-01T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:116', 'invoice receipt:118'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1051,
#     'start_timestamp': Timestamp('2022-07-01 09:10:00+0200', tz='UTC+02:00')}},
#   '1060': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-07-01T15:42:00+02:00',
#    'ocel:omap': ['goods receipt:147', 'invoice receipt:128'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1060,
#     'start_timestamp': Timestamp('2022-07-01 15:42:00+0200', tz='UTC+02:00')}},
#   '1061': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-07-01T15:52:00+02:00',
#    'ocel:omap': ['goods receipt:147', 'invoice receipt:128'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1061,
#     'start_timestamp': Timestamp('2022-07-01 15:52:00+0200', tz='UTC+02:00')}},
#   '1067': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-07-02T01:45:00+02:00',
#    'ocel:omap': ['goods receipt:116',
#     'invoice receipt:118',
#     'purchase_order:76',
#     'payment:57'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1067,
#     'start_timestamp': Timestamp('2022-07-02 01:45:00+0200', tz='UTC+02:00')}},
#   '1139': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-07-07T21:32:00+02:00',
#    'ocel:omap': ['goods receipt:147',
#     'invoice receipt:128',
#     'purchase_order:120',
#     'payment:58'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1139,
#     'start_timestamp': Timestamp('2022-07-07 21:32:00+0200', tz='UTC+02:00')}},
#   '1142': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-07-08T00:05:00+02:00',
#    'ocel:omap': ['goods receipt:117', 'purchase_order:109'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1142,
#     'start_timestamp': Timestamp('2022-07-08 00:05:00+0200', tz='UTC+02:00')}},
#   '1171': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-07-10T00:55:00+02:00',
#    'ocel:omap': ['goods receipt:117', 'invoice receipt:146'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1171,
#     'start_timestamp': Timestamp('2022-07-10 00:55:00+0200', tz='UTC+02:00')}},
#   '1176': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-07-10T12:45:00+02:00',
#    'ocel:omap': ['goods receipt:150', 'purchase_order:122'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1176,
#     'start_timestamp': Timestamp('2022-07-10 12:45:00+0200', tz='UTC+02:00')}},
#   '1182': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-07-11T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:117', 'invoice receipt:146'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1182,
#     'start_timestamp': Timestamp('2022-07-11 09:10:00+0200', tz='UTC+02:00')}},
#   '1185': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-07-11T10:28:00+02:00',
#    'ocel:omap': ['material:263', 'purchase_requisition:97:pr_trigger_97'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1185,
#     'start_timestamp': Timestamp('2022-07-11 10:28:00+0200', tz='UTC+02:00')}},
#   '1201': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-07-12T02:41:00+02:00',
#    'ocel:omap': ['goods receipt:150', 'invoice receipt:152'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1201,
#     'start_timestamp': Timestamp('2022-07-12 02:41:00+0200', tz='UTC+02:00')}},
#   '1207': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-07-12T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:150', 'invoice receipt:152'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1207,
#     'start_timestamp': Timestamp('2022-07-12 09:10:00+0200', tz='UTC+02:00')}},
#   '1257': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-07-15T20:00:00+02:00',
#    'ocel:omap': ['material:284', 'purchase_requisition:105:pr_trigger_105'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1257,
#     'start_timestamp': Timestamp('2022-07-15 20:00:00+0200', tz='UTC+02:00')}},
#   '1287': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-07-17T22:57:00+02:00',
#    'ocel:omap': ['material:263', 'purchase_requisition:97:pr_trigger_97'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1287,
#     'start_timestamp': Timestamp('2022-07-17 22:57:00+0200', tz='UTC+02:00')}},
#   '1303': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-07-18T10:36:00+02:00',
#    'ocel:omap': ['quotation:103', 'purchase_requisition:97:pr_trigger_97'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1303,
#     'start_timestamp': Timestamp('2022-07-18 10:36:00+0200', tz='UTC+02:00')}},
#   '1323': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-07-19T10:09:00+02:00',
#    'ocel:omap': ['goods receipt:150',
#     'invoice receipt:152',
#     'purchase_order:122',
#     'payment:68'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1323,
#     'start_timestamp': Timestamp('2022-07-19 10:09:00+0200', tz='UTC+02:00')}},
#   '1348': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-07-20T21:07:00+02:00',
#    'ocel:omap': ['goods receipt:117',
#     'invoice receipt:146',
#     'purchase_order:109',
#     'payment:67'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1348,
#     'start_timestamp': Timestamp('2022-07-20 21:07:00+0200', tz='UTC+02:00')}},
#   '1352': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-07-21T01:43:00+02:00',
#    'ocel:omap': ['quotation:103', 'purchase_order:171'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1352,
#     'start_timestamp': Timestamp('2022-07-21 01:43:00+0200', tz='UTC+02:00')}},
#   '1358': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-07-21T14:53:00+02:00',
#    'ocel:omap': ['material:284', 'purchase_requisition:105:pr_trigger_105'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1358,
#     'start_timestamp': Timestamp('2022-07-21 14:53:00+0200', tz='UTC+02:00')}},
#   '1364': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-07-21T20:34:00+02:00',
#    'ocel:omap': ['quotation:108', 'purchase_requisition:105:pr_trigger_105'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1364,
#     'start_timestamp': Timestamp('2022-07-21 20:34:00+0200', tz='UTC+02:00')}},
#   '1371': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-07-22T03:24:00+02:00',
#    'ocel:omap': ['quotation:103', 'purchase_order:171'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1371,
#     'start_timestamp': Timestamp('2022-07-22 03:24:00+0200', tz='UTC+02:00')}},
#   '1392': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-07-23T15:30:00+02:00',
#    'ocel:omap': ['goods receipt:189', 'purchase_order:171'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1392,
#     'start_timestamp': Timestamp('2022-07-23 15:30:00+0200', tz='UTC+02:00')}},
#   '1443': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-07-27T14:31:00+02:00',
#    'ocel:omap': ['material:318', 'purchase_requisition:118:pr_trigger_118'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1443,
#     'start_timestamp': Timestamp('2022-07-27 14:31:00+0200', tz='UTC+02:00')}},
#   '1483': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-07-29T12:02:00+02:00',
#    'ocel:omap': ['goods receipt:189', 'invoice receipt:181'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1483,
#     'start_timestamp': Timestamp('2022-07-29 12:02:00+0200', tz='UTC+02:00')}},
#   '1484': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-07-29T12:12:00+02:00',
#    'ocel:omap': ['goods receipt:189', 'invoice receipt:181'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1484,
#     'start_timestamp': Timestamp('2022-07-29 12:12:00+0200', tz='UTC+02:00')}},
#   '1527': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-08-02T00:38:00+02:00',
#    'ocel:omap': ['quotation:108', 'purchase_order:179'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1527,
#     'start_timestamp': Timestamp('2022-08-02 00:38:00+0200', tz='UTC+02:00')}},
#   '1591': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-08-05T10:41:00+02:00',
#    'ocel:omap': ['material:336', 'purchase_requisition:126:pr_trigger_126'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1591,
#     'start_timestamp': Timestamp('2022-08-05 10:41:00+0200', tz='UTC+02:00')}},
#   '1595': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-08-05T13:29:00+02:00',
#    'ocel:omap': ['material:318', 'purchase_requisition:118:pr_trigger_118'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1595,
#     'start_timestamp': Timestamp('2022-08-05 13:29:00+0200', tz='UTC+02:00')}},
#   '1606': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-08-06T03:37:00+02:00',
#    'ocel:omap': ['quotation:119', 'purchase_requisition:118:pr_trigger_118'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1606,
#     'start_timestamp': Timestamp('2022-08-06 03:37:00+0200', tz='UTC+02:00')}},
#   '1634': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-08-07T14:04:00+02:00',
#    'ocel:omap': ['goods receipt:189',
#     'invoice receipt:181',
#     'purchase_order:171',
#     'payment:86'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1634,
#     'start_timestamp': Timestamp('2022-08-07 14:04:00+0200', tz='UTC+02:00')}},
#   '1655': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-08-08T21:33:00+02:00',
#    'ocel:omap': ['material:343', 'purchase_requisition:129:pr_trigger_129'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1655,
#     'start_timestamp': Timestamp('2022-08-08 21:33:00+0200', tz='UTC+02:00')}},
#   '1674': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-08-10T00:24:00+02:00',
#    'ocel:omap': ['quotation:108', 'purchase_order:179'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1674,
#     'start_timestamp': Timestamp('2022-08-10 00:24:00+0200', tz='UTC+02:00')}},
#   '1680': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-08-10T08:53:00+02:00',
#    'ocel:omap': ['material:336', 'purchase_requisition:126:pr_trigger_126'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1680,
#     'start_timestamp': Timestamp('2022-08-10 08:53:00+0200', tz='UTC+02:00')}},
#   '1696': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-08-10T21:10:00+02:00',
#    'ocel:omap': ['quotation:119', 'purchase_order:204'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1696,
#     'start_timestamp': Timestamp('2022-08-10 21:10:00+0200', tz='UTC+02:00')}},
#   '1697': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-08-10T22:01:00+02:00',
#    'ocel:omap': ['quotation:126', 'purchase_requisition:126:pr_trigger_126'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1697,
#     'start_timestamp': Timestamp('2022-08-10 22:01:00+0200', tz='UTC+02:00')}},
#   '1716': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-08-11T15:38:00+02:00',
#    'ocel:omap': ['quotation:126', 'purchase_order:214'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1716,
#     'start_timestamp': Timestamp('2022-08-11 15:38:00+0200', tz='UTC+02:00')}},
#   '1768': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-08-15T08:22:00+02:00',
#    'ocel:omap': ['material:343', 'purchase_requisition:129:pr_trigger_129'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1768,
#     'start_timestamp': Timestamp('2022-08-15 08:22:00+0200', tz='UTC+02:00')}},
#   '1773': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-08-15T09:49:00+02:00',
#    'ocel:omap': ['material:361', 'purchase_requisition:137:pr_trigger_137'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1773,
#     'start_timestamp': Timestamp('2022-08-15 09:49:00+0200', tz='UTC+02:00')}},
#   '1803': {'ocel:activity': 'Approve Purchase Requisition',
#    'ocel:timestamp': '2022-08-16T15:10:00+02:00',
#    'ocel:omap': ['material:361', 'purchase_requisition:137:pr_trigger_137'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1803,
#     'start_timestamp': Timestamp('2022-08-16 15:10:00+0200', tz='UTC+02:00')}},
#   '1807': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-08-16T19:34:00+02:00',
#    'ocel:omap': ['quotation:136', 'purchase_requisition:129:pr_trigger_129'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1807,
#     'start_timestamp': Timestamp('2022-08-16 19:34:00+0200', tz='UTC+02:00')}},
#   '1808': {'ocel:activity': 'Create Request for Quotation',
#    'ocel:timestamp': '2022-08-16T20:32:00+02:00',
#    'ocel:omap': ['quotation:139', 'purchase_requisition:137:pr_trigger_137'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1808,
#     'start_timestamp': Timestamp('2022-08-16 20:32:00+0200', tz='UTC+02:00')}},
#   '1820': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-08-17T11:49:00+02:00',
#    'ocel:omap': ['quotation:119', 'purchase_order:204'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1820,
#     'start_timestamp': Timestamp('2022-08-17 11:49:00+0200', tz='UTC+02:00')}},
#   '1825': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-08-17T14:44:00+02:00',
#    'ocel:omap': ['material:377', 'purchase_requisition:143:pr_trigger_143'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1825,
#     'start_timestamp': Timestamp('2022-08-17 14:44:00+0200', tz='UTC+02:00')}},
#   '1828': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-08-17T16:37:00+02:00',
#    'ocel:omap': ['quotation:136', 'purchase_order:225'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1828,
#     'start_timestamp': Timestamp('2022-08-17 16:37:00+0200', tz='UTC+02:00')}},
#   '1830': {'ocel:activity': 'Create Purchase Order',
#    'ocel:timestamp': '2022-08-17T17:11:00+02:00',
#    'ocel:omap': ['quotation:139', 'purchase_order:226'],
#    'ocel:vmap': {'event_resource': 'Procurement Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1830,
#     'start_timestamp': Timestamp('2022-08-17 17:11:00+0200', tz='UTC+02:00')}},
#   '1834': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-08-17T21:24:00+02:00',
#    'ocel:omap': ['quotation:126', 'purchase_order:214'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1834,
#     'start_timestamp': Timestamp('2022-08-17 21:24:00+0200', tz='UTC+02:00')}},
#   '1835': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-08-17T23:37:00+02:00',
#    'ocel:omap': ['goods receipt:237', 'purchase_order:179'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1835,
#     'start_timestamp': Timestamp('2022-08-17 23:37:00+0200', tz='UTC+02:00')}},
#   '1857': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-08-19T03:45:00+02:00',
#    'ocel:omap': ['quotation:139', 'purchase_order:226'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1857,
#     'start_timestamp': Timestamp('2022-08-19 03:45:00+0200', tz='UTC+02:00')}},
#   '1872': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-08-19T15:42:00+02:00',
#    'ocel:omap': ['material:387', 'purchase_requisition:147:pr_trigger_147'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1872,
#     'start_timestamp': Timestamp('2022-08-19 15:42:00+0200', tz='UTC+02:00')}},
#   '1882': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-08-20T04:32:00+02:00',
#    'ocel:omap': ['goods receipt:237', 'invoice receipt:232'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1882,
#     'start_timestamp': Timestamp('2022-08-20 04:32:00+0200', tz='UTC+02:00')}},
#   '1908': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-08-22T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:237', 'invoice receipt:232'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1908,
#     'start_timestamp': Timestamp('2022-08-22 09:10:00+0200', tz='UTC+02:00')}},
#   '1937': {'ocel:activity': 'Approve Purchase Order',
#    'ocel:timestamp': '2022-08-23T04:43:00+02:00',
#    'ocel:omap': ['quotation:136', 'purchase_order:225'],
#    'ocel:vmap': {'event_resource': 'Procurement Department Manager',
#     'event_lifecycle': 'complete',
#     'event_id': 1937,
#     'start_timestamp': Timestamp('2022-08-23 04:43:00+0200', tz='UTC+02:00')}},
#   '1977': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-08-24T18:35:00+02:00',
#    'ocel:omap': ['goods receipt:272', 'purchase_order:226'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1977,
#     'start_timestamp': Timestamp('2022-08-24 18:35:00+0200', tz='UTC+02:00')}},
#   '1980': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-08-24T19:35:00+02:00',
#    'ocel:omap': ['goods receipt:274', 'purchase_order:225'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 1980,
#     'start_timestamp': Timestamp('2022-08-24 19:35:00+0200', tz='UTC+02:00')}},
#   '2001': {'ocel:activity': 'Create Invoice Receipt',
#    'ocel:timestamp': '2022-08-25T19:33:00+02:00',
#    'ocel:omap': ['goods receipt:274', 'invoice receipt:257'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 2001,
#     'start_timestamp': Timestamp('2022-08-25 19:33:00+0200', tz='UTC+02:00')}},
#   '2011': {'ocel:activity': 'Perform Two-Way Match',
#    'ocel:timestamp': '2022-08-26T09:10:00+02:00',
#    'ocel:omap': ['goods receipt:274', 'invoice receipt:257'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 2011,
#     'start_timestamp': Timestamp('2022-08-26 09:10:00+0200', tz='UTC+02:00')}},
#   '2013': {'ocel:activity': 'Create Goods Receipt',
#    'ocel:timestamp': '2022-08-26T09:31:00+02:00',
#    'ocel:omap': ['goods receipt:266', 'purchase_order:204'],
#    'ocel:vmap': {'event_resource': 'Warehouse Department',
#     'event_lifecycle': 'complete',
#     'event_id': 2013,
#     'start_timestamp': Timestamp('2022-08-26 09:31:00+0200', tz='UTC+02:00')}},
#   '2015': {'ocel:activity': 'Create Purchase Requisition',
#    'ocel:timestamp': '2022-08-26T10:46:00+02:00',
#    'ocel:omap': ['material:393', 'purchase_requisition:152:pr_trigger_152'],
#    'ocel:vmap': {'event_resource': 'Manufacturing Department',
#     'event_lifecycle': 'complete',
#     'event_id': 2015,
#     'start_timestamp': Timestamp('2022-08-26 10:46:00+0200', tz='UTC+02:00')}},
#   '2023': {'ocel:activity': 'Execute Payment',
#    'ocel:timestamp': '2022-08-26T18:33:00+02:00',
#    'ocel:omap': ['goods receipt:274',
#     'invoice receipt:257',
#     'purchase_order:225',
#     'payment:112'],
#    'ocel:vmap': {'event_resource': 'Finance/Account Department',
#     'event_lifecycle': 'complete',
#     'event_id': 2023,
# ...
#   'material:648': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:254:pr_trigger_254': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'material:654': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:257:pr_trigger_257': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'invoice receipt:466': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'purchase_order:413': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'goods receipt:493': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:475': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'quotation:254': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:430': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'payment:214': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'payment:219': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'goods receipt:502': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'material:685': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:270:pr_trigger_270': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:264': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:686': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:271:pr_trigger_271': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:267': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'goods receipt:535': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:504': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'invoice receipt:510': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'goods receipt:521': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'payment:239': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'purchase_order:447': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'payment:217': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'quotation:279': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'payment:237': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'purchase_order:450': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'material:743': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:288:pr_trigger_288': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'goods receipt:556': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'purchase_order:476': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'quotation:283': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'goods receipt:562': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:546': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'invoice receipt:538': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'purchase_order:487': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'invoice receipt:521': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'material:761': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:295:pr_trigger_295': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'payment:251': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'payment:255': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'goods receipt:573': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'material:797': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:309:pr_trigger_309': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'invoice receipt:562': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:254': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'quotation:308': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'payment:263': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'quotation:310': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:542': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'purchase_order:539': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'material:842': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:327:pr_trigger_327': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'goods receipt:564': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'quotation:326': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:860': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:335:pr_trigger_335': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'invoice receipt:620': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'material:864': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:337:pr_trigger_337': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:335': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:572': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'quotation:337': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'payment:287': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'goods receipt:663': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'purchase_order:590': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'purchase_order:587': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'material:900': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:351:pr_trigger_351': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'goods receipt:676': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'quotation:351': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:615': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'invoice receipt:660': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'material:916': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:357:pr_trigger_357': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'material:920': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:359:pr_trigger_359': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'payment:310': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'invoice receipt:682': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:313': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'quotation:360': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'goods receipt:716': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'purchase_order:629': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'goods receipt:707': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:696': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'invoice receipt:697': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'quotation:364': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'goods receipt:725': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'goods receipt:740': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'payment:320': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'invoice receipt:722': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:330': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'invoice receipt:721': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:317': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'material:976': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:381:pr_trigger_381': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:380': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:982': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:384:pr_trigger_384': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:385': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:665': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'purchase_order:657': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'payment:335': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'goods receipt:763': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'purchase_order:635': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'invoice receipt:799': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'goods receipt:803': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'material:1008': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:397:pr_trigger_397': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'goods receipt:807': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:805': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:369': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'payment:363': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'invoice receipt:811': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'goods receipt:837': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:831': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'quotation:403': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:699': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'payment:376': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'goods receipt:846': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'payment:378': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'material:1064': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:417:pr_trigger_417': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'material:1067': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:419:pr_trigger_419': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'invoice receipt:842': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'quotation:418': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:732': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'quotation:419': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:1073': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:422:pr_trigger_422': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'payment:394': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'quotation:421': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:1079': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:426:pr_trigger_426': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'purchase_order:736': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'purchase_order:733': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'quotation:429': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'goods receipt:907': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'purchase_order:746': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'invoice receipt:891': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'goods receipt:908': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'goods receipt:912': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:909': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'goods receipt:899': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:896': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:409': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'invoice receipt:910': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:416': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'payment:419': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'payment:423': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'material:1140': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:449:pr_trigger_449': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:450': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:1178': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:462:pr_trigger_462': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:460': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:1197': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:469:pr_trigger_469': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'purchase_order:781': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'purchase_order:801': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'quotation:472': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'material:1215': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:476:pr_trigger_476': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:475': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:824': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'purchase_order:819': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'goods receipt:992': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'goods receipt:983': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:975': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'invoice receipt:976': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'goods receipt:980': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:983': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'goods receipt:984': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'payment:453': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'invoice receipt:992': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:452': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'material:1264': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:494:pr_trigger_494': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:493': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'payment:459': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'purchase_order:858': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'payment:456': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'material:1274': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:500:pr_trigger_500': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'material:1275': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:501:pr_trigger_501': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:502': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'quotation:501': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'purchase_order:871': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'purchase_order:870': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'goods receipt:1041': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'goods receipt:1054': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'goods receipt:1046': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:1041': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'invoice receipt:1045': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'material:1288': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:509:pr_trigger_509': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'quotation:509': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'invoice receipt:1044': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:486': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'payment:489': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'material:1303': {'ocel:type': 'material', 'ocel:ovmap': {}},
#   'purchase_requisition:514:pr_trigger_514': {'ocel:type': 'purchase_requisition',
#    'ocel:ovmap': {}},
#   'purchase_order:881': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'quotation:514': {'ocel:type': 'quotation', 'ocel:ovmap': {}},
#   'payment:485': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'purchase_order:889': {'ocel:type': 'purchase_order', 'ocel:ovmap': {}},
#   'goods receipt:1085': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:1087': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:502': {'ocel:type': 'payment', 'ocel:ovmap': {}},
#   'goods receipt:1088': {'ocel:type': 'goods receipt', 'ocel:ovmap': {}},
#   'invoice receipt:1090': {'ocel:type': 'invoice receipt', 'ocel:ovmap': {}},
#   'payment:508': {'ocel:type': 'payment', 'ocel:ovmap': {}}}}

# %% [markdown]
# # Process Analysis

# %%
#search for performance factory in the package, this code was taken from ocpm documentation
diag_params = {'measures': ['act_freq', 'arc_freq', 'object_count', 'waiting_time', 'service_time', 'sojourn_time', 'synchronization_time', 'pooling_time', 'lagging_time', 'flow_time'], 'agg': [
    'mean', 'min', 'max'], 'format': 'svg'}
diag = performance_factory.apply(ocpn_fil_p2p, filtered_p2p, parameters=diag_params)
print(f'Diagnostics: {diag}')
gviz = ocpn_vis_factory.apply(
    ocpn_fil_p2p, diagnostics=diag, variant="annotated_with_opera", parameters=diag_params)
ocpn_vis_factory.view(gviz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 #search for performance factory in the package, this code was taken from ocpm documentation
#       2 diag_params = {'measures': ['act_freq', 'arc_freq', 'object_count', 'waiting_time', 'service_time', 'sojourn_time', 'synchronization_time', 'pooling_time', 'lagging_time', 'flow_time'], 'agg': [
#       3     'mean', 'min', 'max'], 'format': 'svg'}
# ----> 4 diag = performance_factory.apply(ocpn_fil_p2p, filtered_p2p, parameters=diag_params)
#       5 print(f'Diagnostics: {diag}')
#       6 gviz = ocpn_vis_factory.apply(
#       7     ocpn_fil_p2p, diagnostics=diag, variant="annotated_with_opera", parameters=diag_params)
#
# NameError: name 'performance_factory' is not defined

# %% [markdown]
# References:
#
# https://ocpa.readthedocs.io/en/latest/index.html
#
# https://github.com/ocpm/ocpa
#
# https://ocpi.ai/#about
