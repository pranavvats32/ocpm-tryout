# %% [markdown]
# ## Dataset Used: intermediate.jsoncel from ocpa github sample logs

# %%
#make a readme and a requirements file

# %% [markdown]
# # Importing Event Log

# %%
import ocpa
from ocpa.objects.log.importer.ocel import factory as ocel_import_factory
intermediate = "intermediate.jsonocel"
ocel_int = ocel_import_factory.apply(intermediate)

# the filetype of the datasets posted on the ocel website does not match the ocpm documentation input filetype
# json vs jsonocel

# %% [markdown]
# # Process Discovery

# %%
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory
from ocpa.visualization.oc_petri_net import factory as ocpn_vis_factory
ocpn_int = ocpn_discovery_factory.apply(ocel_int, parameters={"debug": False})
ocpn_vis_factory.save(ocpn_vis_factory.apply(ocpn_int), "ocpn_int.png")

# %%
#view the ocpm petri net
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# cannot increase the size of image here, tried out matplotlib and graphviz paramtere tuning
img = mpimg.imread("ocpn_int.png")
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()

# %%
#variant calculation and layouting
#The variant layouting just returns a positioning of chevrons as coordinates.
#Instead of drawing the entire process flow directly, the layout algorithm only computes coordinates (X, Y positions) for these elements, 
#so they can be plotted or displayed.


from ocpa.visualization.log.variants import factory as variants_visualization_factory
print("Number of process executions: "+str(len(ocel_int.process_executions)))
print("Number of variants: "+str(len(ocel_int.variants)))
variant_layouting = variants_visualization_factory.apply(ocel_int)
print(variant_layouting[ocel_int.variants[0]])
# Out:
# Number of process executions: 1000
# Number of variants: 917
# ([['Accept offer', [[11, 11], [0, 1]]], ['Pending', [[12, 12], [0]]], ['Cancel offer', [[13, 13], [0, 2]]], ['Cancel offer', [[14, 14], [0, 3]]], ['Cancel offer', [[15, 15], [0, 4]]], ['Create offer', [[6, 6], [0, 2]]], ['Create offer', [[7, 7], [0, 1]]], ['Send (mail and online)', [[8, 8], [1]]], ['Send (mail and online)', [[7, 12], [2]]], ['Create application', [[0, 0], [0]]], ['Accept', [[1, 1], [0]]], ['Create offer', [[2, 2], [0, 4]]], ['Send (mail and online)', [[3, 3], [4]]], ['Complete', [[3, 3], [0]]], ['Call', [[4, 4], [0, 4]]], ['Create offer', [[5, 5], [0, 3]]], ['Send (mail and online)', [[6, 13], [3]]], ['Validate', [[8, 8], [0]]], ['Return', [[9, 10], [1]]], ['Call incomplete files', [[9, 9], [0]]], ['Validate', [[10, 10], [0]]]], {0: ('application', 'application_1'), 1: ('offer', 'offer_1'), 2: ('offer', 'offer_2'), 3: ('offer', 'offer_3'), 4: ('offer', 'offer_4')})

# %% [markdown]
# Hard to display 917 variants, checked on the variant explorer in ocpi
# Only 2 objects , application and offer , only seen application 1 but multiple offers (offer1, offer 2... 5)

# %% [markdown]
# # Precision and Fitness

# %%
from ocpa.algo.conformance.precision_and_fitness import evaluator as quality_measure_factory

precision, fitness = quality_measure_factory.apply(ocel_int, ocpn_int)
print("Precision of IM-discovered net: "+str(precision))
print("Fitness of IM-discovered net: "+str(fitness))
#too long compilation, going over an hour and still no output (maybe cause of the flattening>metrics>combining)

# %% [markdown]
# # Filtered Log

# %% [markdown]
# Filtering variants as precision and fitness gets stuck in a never ending compile loop

# %% [markdown]
# #from ocpa.examplescripts.eventlogmanagement.misc.filter_variants
# # 20% of infrequent variants filtered out
#
# from ocpa.algo.util.filtering.log.variant_filtering import filter_infrequent_variants
# from ocpa.algo.util.process_executions.factory.LEAD_TYPE
# object_types = ["application", "offer"]
# parameters = {"obj_names": object_types,
#               "val_names": [],
#               "act_name": "event_activity",
#               "time_name": "event_timestamp",
#               "sep": ",",
#               "execution_extraction": ocpa.algo.util.process_executions.factory.LEAD_TYPE,
#               "leading_type": object_types[0],
#               "variant_calculation": ocpa.algo.util.variants.factory.TWO_PHASE}
# ocel_fil = ocel_import_factory.apply(file_path=filename, parameters=parameters)
# filtered = filter_infrequent_variants(ocel_fil, 0.2)

# %%
from ocpa.objects.log.util import misc as log_util


def filter_infrequent_variants(ocel, threshold):
    '''
    Filters infrequent variants from an OCEL

    :param ocel: Object-centric event log
    :type ocel: :class:`OCEL <ocpa.objects.log.ocel.OCEL>`

    :param threshold: Cumulative frequency of the most frequent variants to be included.
    :type threshold: float

    :return: Object-centric event log
    :rtype: :class:`OCEL <ocpa.objects.log.ocel.OCEL>`

    '''
    ocel = log_util.copy_log(ocel)
    if threshold > 0.9999:
        return ocel
    v_freq_acc = [sum(ocel.variant_frequencies[0:i+1])
                  for i in range(0, len(ocel.variant_frequencies))]
    last_filtered_variant = len(v_freq_acc)-1
    filtered_variants = []
    for i in range(0, len(v_freq_acc)):
        filtered_variants.append(i)
        if v_freq_acc[i] > threshold:
            last_filtered_variant = i
            break
    # get the relevant objects
    rel_obs = log_util.get_objects_of_variants(ocel, filtered_variants)
    pref_sublog = log_util.remove_object_references(
        ocel.log.log, ocel.object_types, rel_obs)
    sublog = pref_sublog[pref_sublog["event_variant"].apply(
        lambda x: bool(set(x) & set(filtered_variants)))].copy()
    sublog = sublog.drop("event_variant", axis=1)
    sublog = log_util.remove_object_references(
        sublog, ocel.object_types, rel_obs)
    new_log = log_util.copy_log_from_df(sublog, ocel.parameters)
    return new_log

filtered_int= filter_infrequent_variants(ocel_int,0.1)
#anything higher than 0.1 doesnt work

# %% [markdown]
# Filtered Process Discovery

# %%
from ocpa.algo.discovery.ocpn import algorithm as ocpn_discovery_factory
from ocpa.visualization.oc_petri_net import factory as ocpn_vis_factory

ocpn_fil_int = ocpn_discovery_factory.apply(filtered_int, parameters={"debug": False})
print(type(ocpn_fil_int))  # Should be an OCPN object, not OCEL
# Out:
# <class 'ocpa.objects.oc_petri_net.obj.ObjectCentricPetriNet'>

# %%
ocpn_vis_factory.save(ocpn_vis_factory.apply(ocpn_fil_int), "ocpn_fil_int.png")

# %%
img = mpimg.imread("ocpn_fil_int.png")
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()

# %%
from ocpa.algo.conformance.precision_and_fitness import evaluator as quality_measure_factory

precision, fitness = quality_measure_factory.apply(filtered_int, ocpn_fil_int)
print("Precision of IM-discovered net: "+str(precision))
print("Fitness of IM-discovered net: "+str(fitness))
# need to work to better precision
# Out:
# Precision of IM-discovered net: 0.33371831319592427
# Fitness of IM-discovered net: 1.0

# %%
from ocpa.objects.log.exporter.ocel import factory as ocel_export_factory
ocel_export_factory.apply(
    filtered_int, './filtered-intermediate.jsonocel')
# Out:
# {'ocel:global-log': {'ocel:attribute-names': ['event_id'],
#   'ocel:object-types': ['offer', 'application'],
#   'ocel:version': '1.0',
#   'ocel:ordering': 'timestamp'},
#  'ocel:global-event': {'ocel:activity': '__INVALID__'},
#  'ocel:global-object': {'ocel:type': '__INVALID__'},
#  'ocel:events': {'7': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-02T21:20:30.638000',
#    'ocel:omap': ['Application_1825104006'],
#    'ocel:vmap': {'event_id': 7,
#     'start_timestamp': Timestamp('2016-01-02 21:20:30.638000')}},
#   '8': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-02T21:20:30.682000',
#    'ocel:omap': ['Application_1825104006'],
#    'ocel:vmap': {'event_id': 8,
#     'start_timestamp': Timestamp('2016-01-02 21:20:30.682000')}},
#   '26': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-04T11:18:26.275000',
#    'ocel:omap': ['Application_1825104006'],
#    'ocel:vmap': {'event_id': 26,
#     'start_timestamp': Timestamp('2016-01-04 11:18:26.275000')}},
#   '36': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-04T13:25:49.384000',
#    'ocel:omap': ['Application_1825104006'],
#    'ocel:vmap': {'event_id': 36,
#     'start_timestamp': Timestamp('2016-01-04 13:25:49.384000')}},
#   '37': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-04T13:31:22.267000',
#    'ocel:omap': ['Offer_960229906', 'Application_1825104006'],
#    'ocel:vmap': {'event_id': 37,
#     'start_timestamp': Timestamp('2016-01-04 13:31:22.267000')}},
#   '38': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-04T13:32:22.246000',
#    'ocel:omap': ['Offer_1284560550', 'Application_1825104006'],
#    'ocel:vmap': {'event_id': 38,
#     'start_timestamp': Timestamp('2016-01-04 13:32:22.246000')}},
#   '39': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-04T13:34:11.971000',
#    'ocel:omap': ['Offer_1284560550'],
#    'ocel:vmap': {'event_id': 39,
#     'start_timestamp': Timestamp('2016-01-04 13:34:11.971000')}},
#   '40': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-04T13:34:12.011000',
#    'ocel:omap': ['Offer_960229906'],
#    'ocel:vmap': {'event_id': 40,
#     'start_timestamp': Timestamp('2016-01-04 13:34:12.011000')}},
#   '41': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-04T13:34:12.071000',
#    'ocel:omap': ['Offer_960229906', 'Application_1825104006'],
#    'ocel:vmap': {'event_id': 41,
#     'start_timestamp': Timestamp('2016-01-04 13:34:12.071000')}},
#   '83': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-05T17:23:30.997000',
#    'ocel:omap': ['Offer_1780347374', 'Application_1825104006'],
#    'ocel:vmap': {'event_id': 83,
#     'start_timestamp': Timestamp('2016-01-05 17:23:30.997000')}},
#   '84': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-05T17:23:49.904000',
#    'ocel:omap': ['Offer_1982495450', 'Application_1825104006'],
#    'ocel:vmap': {'event_id': 84,
#     'start_timestamp': Timestamp('2016-01-05 17:23:49.904000')}},
#   '85': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-05T17:24:16.991000',
#    'ocel:omap': ['Offer_1982495450'],
#    'ocel:vmap': {'event_id': 85,
#     'start_timestamp': Timestamp('2016-01-05 17:24:16.991000')}},
#   '86': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-05T17:24:17.003000',
#    'ocel:omap': ['Offer_1780347374'],
#    'ocel:vmap': {'event_id': 86,
#     'start_timestamp': Timestamp('2016-01-05 17:24:17.003000')}},
#   '103': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-05T21:23:06.448000',
#    'ocel:omap': ['Application_929235447'],
#    'ocel:vmap': {'event_id': 103,
#     'start_timestamp': Timestamp('2016-01-05 21:23:06.448000')}},
#   '104': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-05T21:23:06.498000',
#    'ocel:omap': ['Application_929235447'],
#    'ocel:vmap': {'event_id': 104,
#     'start_timestamp': Timestamp('2016-01-05 21:23:06.498000')}},
#   '105': {'ocel:activity': 'Handle leads',
#    'ocel:timestamp': '2016-01-06T08:29:56.879000',
#    'ocel:omap': ['Application_929235447'],
#    'ocel:vmap': {'event_id': 105,
#     'start_timestamp': Timestamp('2016-01-06 08:29:56.879000')}},
#   '106': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-06T09:45:34.037000',
#    'ocel:omap': ['Application_1313879847'],
#    'ocel:vmap': {'event_id': 106,
#     'start_timestamp': Timestamp('2016-01-06 09:45:34.037000')}},
#   '107': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-06T09:50:39.446000',
#    'ocel:omap': ['Application_1313879847'],
#    'ocel:vmap': {'event_id': 107,
#     'start_timestamp': Timestamp('2016-01-06 09:50:39.446000')}},
#   '108': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-06T09:56:14.066000',
#    'ocel:omap': ['Offer_1005523025', 'Application_1313879847'],
#    'ocel:vmap': {'event_id': 108,
#     'start_timestamp': Timestamp('2016-01-06 09:56:14.066000')}},
#   '109': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-06T09:56:49.323000',
#    'ocel:omap': ['Offer_1186839614', 'Application_1313879847'],
#    'ocel:vmap': {'event_id': 109,
#     'start_timestamp': Timestamp('2016-01-06 09:56:49.323000')}},
#   '110': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-06T09:58:44.781000',
#    'ocel:omap': ['Offer_1186839614'],
#    'ocel:vmap': {'event_id': 110,
#     'start_timestamp': Timestamp('2016-01-06 09:58:44.781000')}},
#   '111': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-06T09:58:44.786000',
#    'ocel:omap': ['Offer_1005523025'],
#    'ocel:vmap': {'event_id': 111,
#     'start_timestamp': Timestamp('2016-01-06 09:58:44.786000')}},
#   '112': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-06T09:58:44.822000',
#    'ocel:omap': ['Application_1313879847'],
#    'ocel:vmap': {'event_id': 112,
#     'start_timestamp': Timestamp('2016-01-06 09:58:44.822000')}},
#   '113': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-06T09:58:44.858000',
#    'ocel:omap': ['Offer_1005523025', 'Application_1313879847'],
#    'ocel:vmap': {'event_id': 113,
#     'start_timestamp': Timestamp('2016-01-06 09:58:44.858000')}},
#   '191': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-07T11:37:16.861000',
#    'ocel:omap': ['Application_929235447'],
#    'ocel:vmap': {'event_id': 191,
#     'start_timestamp': Timestamp('2016-01-07 11:37:16.861000')}},
#   '192': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-07T11:40:01.649000',
#    'ocel:omap': ['Offer_454127323', 'Application_929235447'],
#    'ocel:vmap': {'event_id': 192,
#     'start_timestamp': Timestamp('2016-01-07 11:40:01.649000')}},
#   '193': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-07T11:41:14.721000',
#    'ocel:omap': ['Offer_454127323'],
#    'ocel:vmap': {'event_id': 193,
#     'start_timestamp': Timestamp('2016-01-07 11:41:14.721000')}},
#   '194': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-07T11:41:14.737000',
#    'ocel:omap': ['Application_929235447'],
#    'ocel:vmap': {'event_id': 194,
#     'start_timestamp': Timestamp('2016-01-07 11:41:14.737000')}},
#   '195': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-07T11:41:14.747000',
#    'ocel:omap': ['Offer_454127323', 'Application_929235447'],
#    'ocel:vmap': {'event_id': 195,
#     'start_timestamp': Timestamp('2016-01-07 11:41:14.747000')}},
#   '196': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-07T14:08:28.042000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 196,
#     'start_timestamp': Timestamp('2016-01-07 14:08:28.042000')}},
#   '197': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-07T14:12:47.646000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 197,
#     'start_timestamp': Timestamp('2016-01-07 14:12:47.646000')}},
#   '198': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-07T14:19:06.679000',
#    'ocel:omap': ['Offer_970444940', 'Application_1089454'],
#    'ocel:vmap': {'event_id': 198,
#     'start_timestamp': Timestamp('2016-01-07 14:19:06.679000')}},
#   '199': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-07T14:19:32.985000',
#    'ocel:omap': ['Offer_970444940'],
#    'ocel:vmap': {'event_id': 199,
#     'start_timestamp': Timestamp('2016-01-07 14:19:32.985000')}},
#   '200': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-07T14:19:33.002000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 200,
#     'start_timestamp': Timestamp('2016-01-07 14:19:33.002000')}},
#   '201': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-07T14:19:33.015000',
#    'ocel:omap': ['Offer_970444940', 'Application_1089454'],
#    'ocel:vmap': {'event_id': 201,
#     'start_timestamp': Timestamp('2016-01-07 14:19:33.015000')}},
#   '421': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-14T14:21:51.149000',
#    'ocel:omap': ['Application_1514861341'],
#    'ocel:vmap': {'event_id': 421,
#     'start_timestamp': Timestamp('2016-01-14 14:21:51.149000')}},
#   '422': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-14T14:21:51.184000',
#    'ocel:omap': ['Application_1514861341'],
#    'ocel:vmap': {'event_id': 422,
#     'start_timestamp': Timestamp('2016-01-14 14:21:51.184000')}},
#   '423': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-14T14:41:49.855000',
#    'ocel:omap': ['Application_1944782361'],
#    'ocel:vmap': {'event_id': 423,
#     'start_timestamp': Timestamp('2016-01-14 14:41:49.855000')}},
#   '424': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-14T14:41:49.908000',
#    'ocel:omap': ['Application_1944782361'],
#    'ocel:vmap': {'event_id': 424,
#     'start_timestamp': Timestamp('2016-01-14 14:41:49.908000')}},
#   '425': {'ocel:activity': 'Handle leads',
#    'ocel:timestamp': '2016-01-14T14:54:04.019000',
#    'ocel:omap': ['Application_1514861341'],
#    'ocel:vmap': {'event_id': 425,
#     'start_timestamp': Timestamp('2016-01-14 14:54:04.019000')}},
#   '426': {'ocel:activity': 'Handle leads',
#    'ocel:timestamp': '2016-01-14T14:57:08.179000',
#    'ocel:omap': ['Application_1944782361'],
#    'ocel:vmap': {'event_id': 426,
#     'start_timestamp': Timestamp('2016-01-14 14:57:08.179000')}},
#   '437': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-14T16:11:04.549000',
#    'ocel:omap': ['Application_1944782361'],
#    'ocel:vmap': {'event_id': 437,
#     'start_timestamp': Timestamp('2016-01-14 16:11:04.549000')}},
#   '438': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-14T16:13:45.515000',
#    'ocel:omap': ['Offer_1962998865', 'Application_1944782361'],
#    'ocel:vmap': {'event_id': 438,
#     'start_timestamp': Timestamp('2016-01-14 16:13:45.515000')}},
#   '439': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-14T16:14:00.540000',
#    'ocel:omap': ['Offer_1962998865'],
#    'ocel:vmap': {'event_id': 439,
#     'start_timestamp': Timestamp('2016-01-14 16:14:00.540000')}},
#   '440': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-14T16:14:00.575000',
#    'ocel:omap': ['Application_1944782361'],
#    'ocel:vmap': {'event_id': 440,
#     'start_timestamp': Timestamp('2016-01-14 16:14:00.575000')}},
#   '441': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-14T16:14:00.587000',
#    'ocel:omap': ['Offer_1962998865', 'Application_1944782361'],
#    'ocel:vmap': {'event_id': 441,
#     'start_timestamp': Timestamp('2016-01-14 16:14:00.587000')}},
#   '442': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-14T16:35:49.983000',
#    'ocel:omap': ['Application_1514861341'],
#    'ocel:vmap': {'event_id': 442,
#     'start_timestamp': Timestamp('2016-01-14 16:35:49.983000')}},
#   '443': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-14T16:36:49.153000',
#    'ocel:omap': ['Offer_52163323', 'Application_1514861341'],
#    'ocel:vmap': {'event_id': 443,
#     'start_timestamp': Timestamp('2016-01-14 16:36:49.153000')}},
#   '444': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-14T16:37:06.359000',
#    'ocel:omap': ['Offer_52163323'],
#    'ocel:vmap': {'event_id': 444,
#     'start_timestamp': Timestamp('2016-01-14 16:37:06.359000')}},
#   '445': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-14T16:37:06.392000',
#    'ocel:omap': ['Application_1514861341'],
#    'ocel:vmap': {'event_id': 445,
#     'start_timestamp': Timestamp('2016-01-14 16:37:06.392000')}},
#   '446': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-14T16:37:06.405000',
#    'ocel:omap': ['Offer_52163323', 'Application_1514861341'],
#    'ocel:vmap': {'event_id': 446,
#     'start_timestamp': Timestamp('2016-01-14 16:37:06.405000')}},
#   '460': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-15T08:52:59.775000',
#    'ocel:omap': ['Application_1679363646'],
#    'ocel:vmap': {'event_id': 460,
#     'start_timestamp': Timestamp('2016-01-15 08:52:59.775000')}},
#   '461': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-15T08:52:59.868000',
#    'ocel:omap': ['Application_1679363646'],
#    'ocel:vmap': {'event_id': 461,
#     'start_timestamp': Timestamp('2016-01-15 08:52:59.868000')}},
#   '488': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-15T16:59:49.438000',
#    'ocel:omap': ['Application_1679363646'],
#    'ocel:vmap': {'event_id': 488,
#     'start_timestamp': Timestamp('2016-01-15 16:59:49.438000')}},
#   '523': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-16T13:52:47.277000',
#    'ocel:omap': ['Application_1679363646'],
#    'ocel:vmap': {'event_id': 523,
#     'start_timestamp': Timestamp('2016-01-16 13:52:47.277000')}},
#   '524': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-16T14:01:54.640000',
#    'ocel:omap': ['Offer_1041402161', 'Application_1679363646'],
#    'ocel:vmap': {'event_id': 524,
#     'start_timestamp': Timestamp('2016-01-16 14:01:54.640000')}},
#   '525': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-16T14:02:24.510000',
#    'ocel:omap': ['Offer_573720538', 'Application_1679363646'],
#    'ocel:vmap': {'event_id': 525,
#     'start_timestamp': Timestamp('2016-01-16 14:02:24.510000')}},
#   '526': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-16T14:04:26.048000',
#    'ocel:omap': ['Offer_573720538'],
#    'ocel:vmap': {'event_id': 526,
#     'start_timestamp': Timestamp('2016-01-16 14:04:26.048000')}},
#   '527': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-16T14:04:26.050000',
#    'ocel:omap': ['Offer_1041402161'],
#    'ocel:vmap': {'event_id': 527,
#     'start_timestamp': Timestamp('2016-01-16 14:04:26.050000')}},
#   '528': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-16T14:04:26.074000',
#    'ocel:omap': ['Offer_1041402161', 'Application_1679363646'],
#    'ocel:vmap': {'event_id': 528,
#     'start_timestamp': Timestamp('2016-01-16 14:04:26.074000')}},
#   '542': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-16T23:38:13.247000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 542,
#     'start_timestamp': Timestamp('2016-01-16 23:38:13.247000')}},
#   '543': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-16T23:38:13.283000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 543,
#     'start_timestamp': Timestamp('2016-01-16 23:38:13.283000')}},
#   '551': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-18T11:04:04.746000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 551,
#     'start_timestamp': Timestamp('2016-01-18 11:04:04.746000')}},
#   '612': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-18T17:16:24.343000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 612,
#     'start_timestamp': Timestamp('2016-01-18 17:16:24.343000')}},
#   '613': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-18T17:23:52.807000',
#    'ocel:omap': ['Offer_726435552', 'Application_537642240'],
#    'ocel:vmap': {'event_id': 613,
#     'start_timestamp': Timestamp('2016-01-18 17:23:52.807000')}},
#   '614': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-18T17:35:29.201000',
#    'ocel:omap': ['Offer_726435552'],
#    'ocel:vmap': {'event_id': 614,
#     'start_timestamp': Timestamp('2016-01-18 17:35:29.201000')}},
#   '615': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-18T17:35:29.225000',
#    'ocel:omap': ['Offer_726435552', 'Application_537642240'],
#    'ocel:vmap': {'event_id': 615,
#     'start_timestamp': Timestamp('2016-01-18 17:35:29.225000')}},
#   '668': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-20T11:06:12.139000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 668,
#     'start_timestamp': Timestamp('2016-01-20 11:06:12.139000')}},
#   '683': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-20T14:20:36.210000',
#    'ocel:omap': ['Application_858669578'],
#    'ocel:vmap': {'event_id': 683,
#     'start_timestamp': Timestamp('2016-01-20 14:20:36.210000')}},
#   '684': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-20T14:20:36.289000',
#    'ocel:omap': ['Application_858669578'],
#    'ocel:vmap': {'event_id': 684,
#     'start_timestamp': Timestamp('2016-01-20 14:20:36.289000')}},
#   '756': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-21T14:17:52.583000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 756,
#     'start_timestamp': Timestamp('2016-01-21 14:17:52.583000')}},
#   '757': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-21T14:21:16.716000',
#    'ocel:omap': ['Offer_421270143', 'Application_1607496739'],
#    'ocel:vmap': {'event_id': 757,
#     'start_timestamp': Timestamp('2016-01-21 14:21:16.716000')}},
#   '758': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-21T14:21:52.947000',
#    'ocel:omap': ['Offer_421270143'],
#    'ocel:vmap': {'event_id': 758,
#     'start_timestamp': Timestamp('2016-01-21 14:21:52.947000')}},
#   '759': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-21T14:21:52.964000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 759,
#     'start_timestamp': Timestamp('2016-01-21 14:21:52.964000')}},
#   '760': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-21T14:21:52.976000',
#    'ocel:omap': ['Offer_421270143', 'Application_1607496739'],
#    'ocel:vmap': {'event_id': 760,
#     'start_timestamp': Timestamp('2016-01-21 14:21:52.976000')}},
#   '761': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-21T15:12:00.066000',
#    'ocel:omap': ['Application_858669578'],
#    'ocel:vmap': {'event_id': 761,
#     'start_timestamp': Timestamp('2016-01-21 15:12:00.066000')}},
#   '815': {'ocel:activity': 'Return',
#    'ocel:timestamp': '2016-01-22T14:54:22.530000',
#    'ocel:omap': ['Offer_421270143'],
#    'ocel:vmap': {'event_id': 815,
#     'start_timestamp': Timestamp('2016-01-22 14:54:22.530000')}},
#   '830': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-22T19:00:41.728000',
#    'ocel:omap': ['Application_136745525'],
#    'ocel:vmap': {'event_id': 830,
#     'start_timestamp': Timestamp('2016-01-22 19:00:41.728000')}},
#   '831': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-22T19:03:40.291000',
#    'ocel:omap': ['Application_136745525'],
#    'ocel:vmap': {'event_id': 831,
#     'start_timestamp': Timestamp('2016-01-22 19:03:40.291000')}},
#   '832': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-22T19:08:11.093000',
#    'ocel:omap': ['Offer_1998263464', 'Application_136745525'],
#    'ocel:vmap': {'event_id': 832,
#     'start_timestamp': Timestamp('2016-01-22 19:08:11.093000')}},
#   '833': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-22T19:08:30.592000',
#    'ocel:omap': ['Offer_1050332412', 'Application_136745525'],
#    'ocel:vmap': {'event_id': 833,
#     'start_timestamp': Timestamp('2016-01-22 19:08:30.592000')}},
#   '834': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-22T19:08:46.242000',
#    'ocel:omap': ['Offer_1050332412'],
#    'ocel:vmap': {'event_id': 834,
#     'start_timestamp': Timestamp('2016-01-22 19:08:46.242000')}},
#   '835': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-22T19:08:46.244000',
#    'ocel:omap': ['Offer_1998263464'],
#    'ocel:vmap': {'event_id': 835,
#     'start_timestamp': Timestamp('2016-01-22 19:08:46.244000')}},
#   '836': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-22T19:08:46.258000',
#    'ocel:omap': ['Application_136745525'],
#    'ocel:vmap': {'event_id': 836,
#     'start_timestamp': Timestamp('2016-01-22 19:08:46.258000')}},
#   '837': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-22T19:08:46.267000',
#    'ocel:omap': ['Offer_1998263464', 'Application_136745525'],
#    'ocel:vmap': {'event_id': 837,
#     'start_timestamp': Timestamp('2016-01-22 19:08:46.267000')}},
#   '844': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-23T11:42:45.944000',
#    'ocel:omap': ['Application_858669578'],
#    'ocel:vmap': {'event_id': 844,
#     'start_timestamp': Timestamp('2016-01-23 11:42:45.944000')}},
#   '845': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-23T11:44:41.671000',
#    'ocel:omap': ['Offer_946254794', 'Application_858669578'],
#    'ocel:vmap': {'event_id': 845,
#     'start_timestamp': Timestamp('2016-01-23 11:44:41.671000')}},
#   '846': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-23T11:44:57.292000',
#    'ocel:omap': ['Offer_946254794'],
#    'ocel:vmap': {'event_id': 846,
#     'start_timestamp': Timestamp('2016-01-23 11:44:57.292000')}},
#   '847': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-23T11:44:57.319000',
#    'ocel:omap': ['Offer_946254794', 'Application_858669578'],
#    'ocel:vmap': {'event_id': 847,
#     'start_timestamp': Timestamp('2016-01-23 11:44:57.319000')}},
#   '879': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-24T14:03:14.058000',
#    'ocel:omap': ['Application_317628520'],
#    'ocel:vmap': {'event_id': 879,
#     'start_timestamp': Timestamp('2016-01-24 14:03:14.058000')}},
#   '880': {'ocel:activity': 'Submit',
#    'ocel:timestamp': '2016-01-24T14:03:14.118000',
#    'ocel:omap': ['Application_317628520'],
#    'ocel:vmap': {'event_id': 880,
#     'start_timestamp': Timestamp('2016-01-24 14:03:14.118000')}},
#   '892': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-25T10:18:38.550000',
#    'ocel:omap': ['Offer_1748817825', 'Application_858669578'],
#    'ocel:vmap': {'event_id': 892,
#     'start_timestamp': Timestamp('2016-01-25 10:18:38.550000')}},
#   '893': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-25T10:18:50.253000',
#    'ocel:omap': ['Offer_1748817825'],
#    'ocel:vmap': {'event_id': 893,
#     'start_timestamp': Timestamp('2016-01-25 10:18:50.253000')}},
#   '907': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-25T12:20:31.765000',
#    'ocel:omap': ['Application_317628520'],
#    'ocel:vmap': {'event_id': 907,
#     'start_timestamp': Timestamp('2016-01-25 12:20:31.765000')}},
#   '965': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-01-25T16:29:29.427000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 965,
#     'start_timestamp': Timestamp('2016-01-25 16:29:29.427000')}},
#   '966': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-01-25T16:29:29.442000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 966,
#     'start_timestamp': Timestamp('2016-01-25 16:29:29.442000')}},
#   '981': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-25T18:08:50.466000',
#    'ocel:omap': ['Application_1242034192'],
#    'ocel:vmap': {'event_id': 981,
#     'start_timestamp': Timestamp('2016-01-25 18:08:50.466000')}},
#   '982': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-25T18:13:55.406000',
#    'ocel:omap': ['Application_1242034192'],
#    'ocel:vmap': {'event_id': 982,
#     'start_timestamp': Timestamp('2016-01-25 18:13:55.406000')}},
#   '983': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-25T18:18:04.328000',
#    'ocel:omap': ['Offer_332167336', 'Application_1242034192'],
#    'ocel:vmap': {'event_id': 983,
#     'start_timestamp': Timestamp('2016-01-25 18:18:04.328000')}},
#   '984': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-25T18:18:16.996000',
#    'ocel:omap': ['Offer_332167336'],
#    'ocel:vmap': {'event_id': 984,
#     'start_timestamp': Timestamp('2016-01-25 18:18:16.996000')}},
#   '985': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-25T18:18:17.009000',
#    'ocel:omap': ['Application_1242034192'],
#    'ocel:vmap': {'event_id': 985,
#     'start_timestamp': Timestamp('2016-01-25 18:18:17.009000')}},
#   '986': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-25T18:18:17.017000',
#    'ocel:omap': ['Offer_332167336', 'Application_1242034192'],
#    'ocel:vmap': {'event_id': 986,
#     'start_timestamp': Timestamp('2016-01-25 18:18:17.017000')}},
#   '987': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-25T18:19:08.763000',
#    'ocel:omap': ['Offer_2087965356', 'Application_1242034192'],
#    'ocel:vmap': {'event_id': 987,
#     'start_timestamp': Timestamp('2016-01-25 18:19:08.763000')}},
#   '988': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-25T18:19:24.497000',
#    'ocel:omap': ['Offer_2087965356'],
#    'ocel:vmap': {'event_id': 988,
#     'start_timestamp': Timestamp('2016-01-25 18:19:24.497000')}},
#   '998': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-25T19:21:00.497000',
#    'ocel:omap': ['Offer_1406430066', 'Application_317628520'],
#    'ocel:vmap': {'event_id': 998,
#     'start_timestamp': Timestamp('2016-01-25 19:21:00.497000')}},
#   '1000': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-25T19:24:17.824000',
#    'ocel:omap': ['Offer_1406430066'],
#    'ocel:vmap': {'event_id': 1000,
#     'start_timestamp': Timestamp('2016-01-25 19:24:17.824000')}},
#   '1001': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-25T19:24:17.838000',
#    'ocel:omap': ['Application_317628520'],
#    'ocel:vmap': {'event_id': 1001,
#     'start_timestamp': Timestamp('2016-01-25 19:24:17.838000')}},
#   '1002': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-25T19:24:17.846000',
#    'ocel:omap': ['Offer_1406430066', 'Application_317628520'],
#    'ocel:vmap': {'event_id': 1002,
#     'start_timestamp': Timestamp('2016-01-25 19:24:17.846000')}},
#   '1105': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-01-26T16:22:52.910000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 1105,
#     'start_timestamp': Timestamp('2016-01-26 16:22:52.910000')}},
#   '1106': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-01-26T16:22:52.922000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 1106,
#     'start_timestamp': Timestamp('2016-01-26 16:22:52.922000')}},
#   '1119': {'ocel:activity': 'Create application',
#    'ocel:timestamp': '2016-01-26T17:05:53.383000',
#    'ocel:omap': ['Application_1805495181'],
#    'ocel:vmap': {'event_id': 1119,
#     'start_timestamp': Timestamp('2016-01-26 17:05:53.383000')}},
#   '1120': {'ocel:activity': 'Accept',
#    'ocel:timestamp': '2016-01-26T17:09:48.541000',
#    'ocel:omap': ['Application_1805495181'],
#    'ocel:vmap': {'event_id': 1120,
#     'start_timestamp': Timestamp('2016-01-26 17:09:48.541000')}},
#   '1121': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-26T17:13:08.586000',
#    'ocel:omap': ['Offer_648044611', 'Application_1805495181'],
#    'ocel:vmap': {'event_id': 1121,
#     'start_timestamp': Timestamp('2016-01-26 17:13:08.586000')}},
#   '1122': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-26T17:13:19.423000',
#    'ocel:omap': ['Offer_648044611'],
#    'ocel:vmap': {'event_id': 1122,
#     'start_timestamp': Timestamp('2016-01-26 17:13:19.423000')}},
#   '1123': {'ocel:activity': 'Complete',
#    'ocel:timestamp': '2016-01-26T17:13:19.439000',
#    'ocel:omap': ['Application_1805495181'],
#    'ocel:vmap': {'event_id': 1123,
#     'start_timestamp': Timestamp('2016-01-26 17:13:19.439000')}},
#   '1124': {'ocel:activity': 'Call',
#    'ocel:timestamp': '2016-01-26T17:13:19.448000',
#    'ocel:omap': ['Offer_648044611', 'Application_1805495181'],
#    'ocel:vmap': {'event_id': 1124,
#     'start_timestamp': Timestamp('2016-01-26 17:13:19.448000')}},
#   '1164': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-01-27T10:52:03.186000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1164,
#     'start_timestamp': Timestamp('2016-01-27 10:52:03.186000')}},
#   '1165': {'ocel:activity': 'Return',
#    'ocel:timestamp': '2016-01-27T10:53:28.408000',
#    'ocel:omap': ['Offer_970444940'],
#    'ocel:vmap': {'event_id': 1165,
#     'start_timestamp': Timestamp('2016-01-27 10:53:28.408000')}},
#   '1177': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-01-27T12:08:00.522000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1177,
#     'start_timestamp': Timestamp('2016-01-27 12:08:00.522000')}},
#   '1190': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-01-27T14:24:51.352000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 1190,
#     'start_timestamp': Timestamp('2016-01-27 14:24:51.352000')}},
#   '1191': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-01-27T14:24:51.360000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 1191,
#     'start_timestamp': Timestamp('2016-01-27 14:24:51.360000')}},
#   '1200': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-27T16:10:59.338000',
#    'ocel:omap': ['Offer_1197044705', 'Application_1607496739'],
#    'ocel:vmap': {'event_id': 1200,
#     'start_timestamp': Timestamp('2016-01-27 16:10:59.338000')}},
#   '1201': {'ocel:activity': 'Send (online)',
#    'ocel:timestamp': '2016-01-27T16:11:22.822000',
#    'ocel:omap': ['Offer_1197044705'],
#    'ocel:vmap': {'event_id': 1201,
#     'start_timestamp': Timestamp('2016-01-27 16:11:22.822000')}},
#   '1202': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-01-27T16:44:41.489000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1202,
#     'start_timestamp': Timestamp('2016-01-27 16:44:41.489000')}},
#   '1228': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-01-28T11:08:16.732000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1228,
#     'start_timestamp': Timestamp('2016-01-28 11:08:16.732000')}},
#   '1231': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-28T11:22:09.093000',
#    'ocel:omap': ['Offer_1155769455', 'Application_1089454'],
#    'ocel:vmap': {'event_id': 1231,
#     'start_timestamp': Timestamp('2016-01-28 11:22:09.093000')}},
#   '1232': {'ocel:activity': 'Send (online)',
#    'ocel:timestamp': '2016-01-28T11:22:23.242000',
#    'ocel:omap': ['Offer_1155769455'],
#    'ocel:vmap': {'event_id': 1232,
#     'start_timestamp': Timestamp('2016-01-28 11:22:23.242000')}},
#   '1249': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-01-28T13:35:09.025000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1249,
#     'start_timestamp': Timestamp('2016-01-28 13:35:09.025000')}},
#   '1278': {'ocel:activity': 'Return',
#    'ocel:timestamp': '2016-01-29T08:27:21.321000',
#    'ocel:omap': ['Offer_726435552'],
#    'ocel:vmap': {'event_id': 1278,
#     'start_timestamp': Timestamp('2016-01-29 08:27:21.321000')}},
#   '1299': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-01-29T09:31:09.557000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1299,
#     'start_timestamp': Timestamp('2016-01-29 09:31:09.557000')}},
#   '1345': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T10:50:37.024000',
#    'ocel:omap': ['Offer_201843452', 'Application_1825104006'],
#    'ocel:vmap': {'event_id': 1345,
#     'start_timestamp': Timestamp('2016-01-29 10:50:37.024000')}},
#   '1346': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T10:50:48.865000',
#    'ocel:omap': ['Offer_201843452'],
#    'ocel:vmap': {'event_id': 1346,
#     'start_timestamp': Timestamp('2016-01-29 10:50:48.865000')}},
#   '1355': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:09:59.735000',
#    'ocel:omap': ['Offer_1273145401', 'Application_1242034192'],
#    'ocel:vmap': {'event_id': 1355,
#     'start_timestamp': Timestamp('2016-01-29 11:09:59.735000')}},
#   '1356': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:10:16.179000',
#    'ocel:omap': ['Offer_233518168', 'Application_1242034192'],
#    'ocel:vmap': {'event_id': 1356,
#     'start_timestamp': Timestamp('2016-01-29 11:10:16.179000')}},
#   '1357': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:10:33.800000',
#    'ocel:omap': ['Offer_233518168'],
#    'ocel:vmap': {'event_id': 1357,
#     'start_timestamp': Timestamp('2016-01-29 11:10:33.800000')}},
#   '1358': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:10:33.801000',
#    'ocel:omap': ['Offer_1273145401'],
#    'ocel:vmap': {'event_id': 1358,
#     'start_timestamp': Timestamp('2016-01-29 11:10:33.801000')}},
#   '1376': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:33:42.798000',
#    'ocel:omap': ['Offer_1509313289', 'Application_858669578'],
#    'ocel:vmap': {'event_id': 1376,
#     'start_timestamp': Timestamp('2016-01-29 11:33:42.798000')}},
#   '1377': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:33:54.641000',
#    'ocel:omap': ['Offer_1509313289'],
#    'ocel:vmap': {'event_id': 1377,
#     'start_timestamp': Timestamp('2016-01-29 11:33:54.641000')}},
#   '1390': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:39:50.996000',
#    'ocel:omap': ['Offer_1479717640', 'Application_1514861341'],
#    'ocel:vmap': {'event_id': 1390,
#     'start_timestamp': Timestamp('2016-01-29 11:39:50.996000')}},
#   '1391': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:40:01.875000',
#    'ocel:omap': ['Offer_1479717640'],
#    'ocel:vmap': {'event_id': 1391,
#     'start_timestamp': Timestamp('2016-01-29 11:40:01.875000')}},
#   '1392': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:42:06.153000',
#    'ocel:omap': ['Offer_1920136385', 'Application_1805495181'],
#    'ocel:vmap': {'event_id': 1392,
#     'start_timestamp': Timestamp('2016-01-29 11:42:06.153000')}},
#   '1393': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:42:22.046000',
#    'ocel:omap': ['Offer_1920136385'],
#    'ocel:vmap': {'event_id': 1393,
#     'start_timestamp': Timestamp('2016-01-29 11:42:22.046000')}},
#   '1394': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:43:00.311000',
#    'ocel:omap': ['Offer_1742928390', 'Application_1944782361'],
#    'ocel:vmap': {'event_id': 1394,
#     'start_timestamp': Timestamp('2016-01-29 11:43:00.311000')}},
#   '1395': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:43:20.205000',
#    'ocel:omap': ['Offer_1742928390'],
#    'ocel:vmap': {'event_id': 1395,
#     'start_timestamp': Timestamp('2016-01-29 11:43:20.205000')}},
#   '1400': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:48:16.697000',
#    'ocel:omap': ['Offer_524567372', 'Application_929235447'],
#    'ocel:vmap': {'event_id': 1400,
#     'start_timestamp': Timestamp('2016-01-29 11:48:16.697000')}},
#   '1401': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:48:27.549000',
#    'ocel:omap': ['Offer_524567372'],
#    'ocel:vmap': {'event_id': 1401,
#     'start_timestamp': Timestamp('2016-01-29 11:48:27.549000')}},
#   '1409': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:52:14.582000',
#    'ocel:omap': ['Offer_552644105', 'Application_1313879847'],
#    'ocel:vmap': {'event_id': 1409,
#     'start_timestamp': Timestamp('2016-01-29 11:52:14.582000')}},
#   '1410': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T11:52:40.749000',
#    'ocel:omap': ['Offer_365844741', 'Application_1679363646'],
#    'ocel:vmap': {'event_id': 1410,
#     'start_timestamp': Timestamp('2016-01-29 11:52:40.749000')}},
#   '1411': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:53:12.085000',
#    'ocel:omap': ['Offer_552644105'],
#    'ocel:vmap': {'event_id': 1411,
#     'start_timestamp': Timestamp('2016-01-29 11:53:12.085000')}},
#   '1412': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T11:53:15.069000',
#    'ocel:omap': ['Offer_365844741'],
#    'ocel:vmap': {'event_id': 1412,
#     'start_timestamp': Timestamp('2016-01-29 11:53:15.069000')}},
#   '1435': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T14:03:42.777000',
#    'ocel:omap': ['Offer_1312758445', 'Application_1805495181'],
#    'ocel:vmap': {'event_id': 1435,
#     'start_timestamp': Timestamp('2016-01-29 14:03:42.777000')}},
#   '1436': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T14:03:57.133000',
#    'ocel:omap': ['Offer_1312758445'],
#    'ocel:vmap': {'event_id': 1436,
#     'start_timestamp': Timestamp('2016-01-29 14:03:57.133000')}},
#   '1457': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T14:33:11.309000',
#    'ocel:omap': ['Offer_1385372401', 'Application_929235447'],
#    'ocel:vmap': {'event_id': 1457,
#     'start_timestamp': Timestamp('2016-01-29 14:33:11.309000')}},
#   '1458': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T14:33:21.683000',
#    'ocel:omap': ['Offer_1385372401'],
#    'ocel:vmap': {'event_id': 1458,
#     'start_timestamp': Timestamp('2016-01-29 14:33:21.683000')}},
#   '1459': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T14:37:00.773000',
#    'ocel:omap': ['Offer_1097745455', 'Application_1313879847'],
#    'ocel:vmap': {'event_id': 1459,
#     'start_timestamp': Timestamp('2016-01-29 14:37:00.773000')}},
#   '1460': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T14:37:13.552000',
#    'ocel:omap': ['Offer_1097745455'],
#    'ocel:vmap': {'event_id': 1460,
#     'start_timestamp': Timestamp('2016-01-29 14:37:13.552000')}},
#   '1473': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T15:11:16.212000',
#    'ocel:omap': ['Offer_617197648', 'Application_136745525'],
#    'ocel:vmap': {'event_id': 1473,
#     'start_timestamp': Timestamp('2016-01-29 15:11:16.212000')}},
#   '1474': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T15:11:26.999000',
#    'ocel:omap': ['Offer_617197648'],
#    'ocel:vmap': {'event_id': 1474,
#     'start_timestamp': Timestamp('2016-01-29 15:11:26.999000')}},
#   '1487': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T15:30:56.416000',
#    'ocel:omap': ['Offer_1886787133', 'Application_1514861341'],
#    'ocel:vmap': {'event_id': 1487,
#     'start_timestamp': Timestamp('2016-01-29 15:30:56.416000')}},
#   '1488': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T15:31:07.923000',
#    'ocel:omap': ['Offer_1886787133'],
#    'ocel:vmap': {'event_id': 1488,
#     'start_timestamp': Timestamp('2016-01-29 15:31:07.923000')}},
#   '1490': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T15:33:20.358000',
#    'ocel:omap': ['Offer_278455731', 'Application_1944782361'],
#    'ocel:vmap': {'event_id': 1490,
#     'start_timestamp': Timestamp('2016-01-29 15:33:20.358000')}},
#   '1492': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T15:33:37.018000',
#    'ocel:omap': ['Offer_278455731'],
#    'ocel:vmap': {'event_id': 1492,
#     'start_timestamp': Timestamp('2016-01-29 15:33:37.018000')}},
#   '1497': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-01-29T15:43:45.387000',
#    'ocel:omap': ['Offer_691254459', 'Application_1679363646'],
#    'ocel:vmap': {'event_id': 1497,
#     'start_timestamp': Timestamp('2016-01-29 15:43:45.387000')}},
#   '1498': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-01-29T15:44:03.599000',
#    'ocel:omap': ['Offer_691254459'],
#    'ocel:vmap': {'event_id': 1498,
#     'start_timestamp': Timestamp('2016-01-29 15:44:03.599000')}},
#   '1511': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-01-29T16:03:56.562000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1511,
#     'start_timestamp': Timestamp('2016-01-29 16:03:56.562000')}},
#   '1569': {'ocel:activity': 'Return',
#    'ocel:timestamp': '2016-02-01T10:00:30.355000',
#    'ocel:omap': ['Offer_1155769455'],
#    'ocel:vmap': {'event_id': 1569,
#     'start_timestamp': Timestamp('2016-02-01 10:00:30.355000')}},
#   '1579': {'ocel:activity': 'Accept offer',
#    'ocel:timestamp': '2016-02-01T10:54:36.439000',
#    'ocel:omap': ['Offer_1155769455', 'Application_1089454'],
#    'ocel:vmap': {'event_id': 1579,
#     'start_timestamp': Timestamp('2016-02-01 10:54:36.439000')}},
#   '1580': {'ocel:activity': 'Pending',
#    'ocel:timestamp': '2016-02-01T10:54:36.446000',
#    'ocel:omap': ['Application_1089454'],
#    'ocel:vmap': {'event_id': 1580,
#     'start_timestamp': Timestamp('2016-02-01 10:54:36.446000')}},
#   '1581': {'ocel:activity': 'Cancel offer',
#    'ocel:timestamp': '2016-02-01T10:54:36.470000',
#    'ocel:omap': ['Offer_970444940', 'Application_1089454'],
#    'ocel:vmap': {'event_id': 1581,
#     'start_timestamp': Timestamp('2016-02-01 10:54:36.470000')}},
#   '1585': {'ocel:activity': 'Return',
#    'ocel:timestamp': '2016-02-01T11:14:50.878000',
#    'ocel:omap': ['Offer_1197044705'],
#    'ocel:vmap': {'event_id': 1585,
#     'start_timestamp': Timestamp('2016-02-01 11:14:50.878000')}},
#   '1586': {'ocel:activity': 'Accept offer',
#    'ocel:timestamp': '2016-02-01T11:15:19.296000',
#    'ocel:omap': ['Offer_1197044705', 'Application_1607496739'],
#    'ocel:vmap': {'event_id': 1586,
#     'start_timestamp': Timestamp('2016-02-01 11:15:19.296000')}},
#   '1587': {'ocel:activity': 'Pending',
#    'ocel:timestamp': '2016-02-01T11:15:19.305000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 1587,
#     'start_timestamp': Timestamp('2016-02-01 11:15:19.305000')}},
#   '1588': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-02-01T11:15:19.309000',
#    'ocel:omap': ['Application_1607496739'],
#    'ocel:vmap': {'event_id': 1588,
#     'start_timestamp': Timestamp('2016-02-01 11:15:19.309000')}},
#   '1589': {'ocel:activity': 'Cancel offer',
#    'ocel:timestamp': '2016-02-01T11:15:19.327000',
#    'ocel:omap': ['Offer_421270143', 'Application_1607496739'],
#    'ocel:vmap': {'event_id': 1589,
#     'start_timestamp': Timestamp('2016-02-01 11:15:19.327000')}},
#   '1622': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-02-01T15:57:25.430000',
#    'ocel:omap': ['Offer_2042742939', 'Application_1679363646'],
#    'ocel:vmap': {'event_id': 1622,
#     'start_timestamp': Timestamp('2016-02-01 15:57:25.430000')}},
#   '1623': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-02-01T15:57:46.018000',
#    'ocel:omap': ['Offer_2042742939'],
#    'ocel:vmap': {'event_id': 1623,
#     'start_timestamp': Timestamp('2016-02-01 15:57:46.018000')}},
#   '1624': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-02-01T15:58:45.582000',
#    'ocel:omap': ['Offer_1536198680', 'Application_1313879847'],
#    'ocel:vmap': {'event_id': 1624,
#     'start_timestamp': Timestamp('2016-02-01 15:58:45.582000')}},
#   '1625': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-02-01T15:59:02.780000',
#    'ocel:omap': ['Offer_1536198680'],
#    'ocel:vmap': {'event_id': 1625,
#     'start_timestamp': Timestamp('2016-02-01 15:59:02.780000')}},
#   '1629': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-02-01T16:14:22.902000',
#    'ocel:omap': ['Offer_973694397', 'Application_929235447'],
#    'ocel:vmap': {'event_id': 1629,
#     'start_timestamp': Timestamp('2016-02-01 16:14:22.902000')}},
#   '1630': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-02-01T16:14:41.153000',
#    'ocel:omap': ['Offer_973694397'],
#    'ocel:vmap': {'event_id': 1630,
#     'start_timestamp': Timestamp('2016-02-01 16:14:41.153000')}},
#   '1634': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-02-01T16:30:06.046000',
#    'ocel:omap': ['Offer_788969230', 'Application_1944782361'],
#    'ocel:vmap': {'event_id': 1634,
#     'start_timestamp': Timestamp('2016-02-01 16:30:06.046000')}},
#   '1635': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-02-01T16:30:26.451000',
#    'ocel:omap': ['Offer_788969230'],
#    'ocel:vmap': {'event_id': 1635,
#     'start_timestamp': Timestamp('2016-02-01 16:30:26.451000')}},
#   '1636': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-02-01T16:40:14.745000',
#    'ocel:omap': ['Offer_1049734488', 'Application_1805495181'],
#    'ocel:vmap': {'event_id': 1636,
#     'start_timestamp': Timestamp('2016-02-01 16:40:14.745000')}},
#   '1637': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-02-01T16:40:38.993000',
#    'ocel:omap': ['Offer_1049734488'],
#    'ocel:vmap': {'event_id': 1637,
#     'start_timestamp': Timestamp('2016-02-01 16:40:38.993000')}},
#   '1638': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-02-01T16:59:28.067000',
#    'ocel:omap': ['Offer_1829400135', 'Application_1514861341'],
#    'ocel:vmap': {'event_id': 1638,
#     'start_timestamp': Timestamp('2016-02-01 16:59:28.067000')}},
#   '1639': {'ocel:activity': 'Send (mail and online)',
#    'ocel:timestamp': '2016-02-01T16:59:38.874000',
#    'ocel:omap': ['Offer_1829400135'],
#    'ocel:vmap': {'event_id': 1639,
#     'start_timestamp': Timestamp('2016-02-01 16:59:38.874000')}},
#   '1675': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-02-02T09:56:05.240000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 1675,
#     'start_timestamp': Timestamp('2016-02-02 09:56:05.240000')}},
#   '1685': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-02-02T10:48:32.372000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 1685,
#     'start_timestamp': Timestamp('2016-02-02 10:48:32.372000')}},
#   '1687': {'ocel:activity': 'Return',
#    'ocel:timestamp': '2016-02-02T10:53:35.296000',
#    'ocel:omap': ['Offer_1406430066'],
#    'ocel:vmap': {'event_id': 1687,
#     'start_timestamp': Timestamp('2016-02-02 10:53:35.296000')}},
#   '1689': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-02-02T11:12:53.099000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 1689,
#     'start_timestamp': Timestamp('2016-02-02 11:12:53.099000')}},
#   '1690': {'ocel:activity': 'Call incomplete files',
#    'ocel:timestamp': '2016-02-02T11:12:53.108000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 1690,
#     'start_timestamp': Timestamp('2016-02-02 11:12:53.108000')}},
#   '1702': {'ocel:activity': 'Create offer',
#    'ocel:timestamp': '2016-02-02T12:11:06.097000',
#    'ocel:omap': ['Offer_296916485', 'Application_537642240'],
#    'ocel:vmap': {'event_id': 1702,
#     'start_timestamp': Timestamp('2016-02-02 12:11:06.097000')}},
#   '1703': {'ocel:activity': 'Send (online)',
#    'ocel:timestamp': '2016-02-02T12:11:22.126000',
#    'ocel:omap': ['Offer_296916485'],
#    'ocel:vmap': {'event_id': 1703,
#     'start_timestamp': Timestamp('2016-02-02 12:11:22.126000')}},
#   '1807': {'ocel:activity': 'Return',
#    'ocel:timestamp': '2016-02-03T14:57:24.131000',
#    'ocel:omap': ['Offer_296916485'],
#    'ocel:vmap': {'event_id': 1807,
#     'start_timestamp': Timestamp('2016-02-03 14:57:24.131000')}},
#   '1808': {'ocel:activity': 'Validate',
#    'ocel:timestamp': '2016-02-03T14:59:35.668000',
#    'ocel:omap': ['Application_537642240'],
#    'ocel:vmap': {'event_id': 1808,
#     'start_timestamp': Timestamp('2016-02-03 14:59:35.668000')}},
#   '1809': {'ocel:activity': 'Call incomplete files',
# ...
#   'Offer_1152682887': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_978933800': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_684396319': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1609742208': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1176294714': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1424330103': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_688185359': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1770512712': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_246393112': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1173329074': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_935000237': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1438474091': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_271501220': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_286002318': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1704428084': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_542058089': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_17275553': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_327692113': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1659102703': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_750285384': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1979153568': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_309042709': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1813871061': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_259831638': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1677498057': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_294028593': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_415635439': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_2075045295': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_2019088836': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1829514623': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_603081990': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1750027000': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_59954720': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1738766936': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1602426319': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1992804847': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2120535278': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_623401209': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_936126320': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2094795118': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1885688743': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1882932059': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1526704951': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1754610695': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1952889508': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2013813322': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1956658171': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1191319978': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1236960093': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_481650665': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1910646287': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1222657932': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_522580673': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1597050170': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1503335927': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1178999677': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_995445687': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_320597520': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_198016680': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_2083746765': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_587809253': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1186003933': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1095569944': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1830405893': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_970092205': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1985641637': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_394964642': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_88921354': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2021390918': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1752846821': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_402279125': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1355219967': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_401024536': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1547546515': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_2027060559': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_636117217': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1293571806': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1999378734': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1977263041': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1588082560': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1178004063': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_135266240': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_511174696': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1311701806': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_283722286': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_2078872716': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_205010821': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1254125100': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1476282671': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_2072188464': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_382130883': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_446454929': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_2146276332': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1981557695': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_483924267': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_828666282': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1657574853': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1200076658': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_785836898': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1101860607': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_267895986': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1798948437': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_591122536': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_400113426': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1342644312': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_302362725': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1318974251': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1426996448': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_535771661': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_413990914': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1028865435': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2067918287': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_940433011': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_76670345': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_110085162': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_910458579': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_555561173': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2080463621': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_150536803': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1155624509': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_615525910': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1707761373': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_187739322': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1093899105': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1112791540': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_400421751': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_577450785': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1294153137': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_981000084': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1592138056': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_34152516': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_805253858': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_616186984': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1207159027': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_262237882': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1192136675': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_36658111': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_321605152': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1787530703': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_305579821': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_719675439': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_363052183': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_788088433': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_41959878': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_742661233': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1031044836': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1721666060': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_946633977': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_2141707013': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_3763690': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_22178222': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_249910385': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_955141675': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_9571945': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2052629962': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1569414947': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1971001747': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1661991042': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_680044383': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_332704649': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_518856803': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_329522221': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_229012140': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1141584182': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_792122347': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1449066412': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1666465764': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1950746270': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1099472941': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_332054715': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1751763296': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_597721884': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_453841402': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1851062351': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_637222323': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1445621609': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1378977237': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2095342671': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_864348276': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2066024245': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1215541224': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1505658776': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1337059224': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_139415997': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_99921467': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1122482586': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1800495124': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_62526656': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_776975385': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2140538963': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1980172661': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1087237041': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_789072844': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_443770026': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1561581762': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1656059948': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1042047447': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_492857288': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1158368771': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1118094444': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_104012014': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_293493145': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_146968001': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_414900485': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_402162850': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1843954143': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_379598624': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1311072148': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1620146581': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2120263065': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1959891562': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Application_1473159696': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1775870219': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_923297082': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1484955476': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1009746027': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1760057821': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_97250942': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1273851398': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1623677902': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_301438770': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1335998696': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1455109915': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1366758339': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_106690110': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_2026904009': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1845800814': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1918917666': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1612709224': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_396825904': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_970287789': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1830330262': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1485751011': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_1974498231': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_438755012': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Application_1982634211': {'ocel:type': 'application', 'ocel:ovmap': {}},
#   'Offer_1416906222': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_75180965': {'ocel:type': 'offer', 'ocel:ovmap': {}},
#   'Offer_70311111': {'ocel:type': 'offer', 'ocel:ovmap': {}}}}

# %% [markdown]
# # Process Analysis

# %%
#search for performance factory in the package, this code was taken from ocpm documentation
diag_params = {'measures': ['act_freq', 'arc_freq', 'object_count', 'waiting_time', 'service_time', 'sojourn_time', 'synchronization_time', 'pooling_time', 'lagging_time', 'flow_time'], 'agg': [
    'mean', 'min', 'max'], 'format': 'svg'}
diag = performance_factory.apply(ocpn_fil_int, filtered_int, parameters=diag_params)
print(f'Diagnostics: {diag}')
gviz = ocpn_vis_factory.apply(
    ocpn_fil_int, diagnostics=diag, variant="annotated_with_opera", parameters=diag_params)
ocpn_vis_factory.view(gviz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 #search for performance factory in the package, this code was taken from ocpm documentation
#       2 diag_params = {'measures': ['act_freq', 'arc_freq', 'object_count', 'waiting_time', 'service_time', 'sojourn_time', 'synchronization_time', 'pooling_time', 'lagging_time', 'flow_time'], 'agg': [
#       3     'mean', 'min', 'max'], 'format': 'svg'}
# ----> 4 diag = performance_factory.apply(ocpn_fil_int, filtered_int, parameters=diag_params)
#       5 print(f'Diagnostics: {diag}')
#       6 gviz = ocpn_vis_factory.apply(
#       7     ocpn_fil_int, diagnostics=diag, variant="annotated_with_opera", parameters=diag_params)
#
# NameError: name 'performance_factory' is not defined

# %% [markdown]
# References:
#
# https://ocpa.readthedocs.io/en/latest/index.html
#
# https://github.com/ocpm/ocpa
#
# https://ocpi.ai/#about
